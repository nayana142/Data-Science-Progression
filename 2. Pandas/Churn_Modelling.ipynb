# %% [markdown]
# # Data Description

# %% [markdown]
# SHORT DESCRIPTION ABOUT CHURN MODELLING DATASET
#
#
# * CustomerID: A unique identifier for each customer.
#
# * Surname: The customer's last name.
#
# * CreditScore: A numeric score representing the creditworthiness of the customer.
#
# * Geography: The country or region where the customer resides.
#
# * Gender: The gender of the customer (e.g., Male, Female).
#
# * Age: The age of the customer.
#
# * Tenure: The number of years the customer has been with the company.
#
# * Balance : The amount of money the customer currently has in their account(s).
#
# * NumOfProducts : The number of products the customer has purchased or is subscribed to.
#
# * HasCrCard: A binary indicator (Yes/No or 1/0) indicating whether the customer has a credit card.
#
# * IsActiveMember: A binary indicator showing if the customer is an active member (Yes/No or 1/0).
#
# * EstimatedSalary : The estimated annual salary of the customer.
#
# * Exited : The target variable, indicating whether the customer has left the company (Yes/No or 1/0).

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Churn_Modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# # Basic Info

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.size
# Out:
# 140000

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.describe(include='object')
# Out:
#        Surname Geography Gender
# count    10000     10000  10000
# unique    2932         3      2
# top      Smith    France   Male
# freq        32      5014   5457

# %%
df.describe(include='all')
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# count   10000.000000  10000.000000   10000.000000   10000.000000  10000.00000
# unique           NaN           NaN            NaN            NaN          NaN
# top              NaN           NaN            NaN            NaN          NaN
# freq             NaN           NaN            NaN            NaN          NaN
# mean       38.921800      5.012800   76485.889288       1.530200      0.70550
# std        10.487806      2.892174   62397.405202       0.581654      0.45584
# min        18.000000      0.000000       0.000000       1.000000      0.00000
# 25%        32.000000      3.000000       0.000000       1.000000      0.00000
# 50%        37.000000      5.000000   97198.540000       1.000000      1.00000
# 75%        44.000000      7.000000  127644.240000       2.000000      1.00000
# max        92.000000     10.000000  250898.090000       4.000000      1.00000
#
#         IsActiveMember  EstimatedSalary        Exited
# count     10000.000000     10000.000000  10000.000000
# unique             NaN              NaN           NaN
# top                NaN              NaN           NaN
# freq               NaN              NaN           NaN
# mean          0.515100    100090.239881      0.203700
# std           0.499797     57510.492818      0.402769
# min           0.000000        11.580000      0.000000
# 25%           0.000000     51002.110000      0.000000
# 50%           1.000000    100193.915000      0.000000
# 75%           1.000000    149388.247500      0.000000
# max           1.000000    199992.480000      1.000000

# %%
df.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %%
df.ndim
# Out:
# 2

# %%
df.value_counts()
# Out:
# RowNumber  CustomerId  Surname     CreditScore  Geography  Gender  Age  Tenure  Balance    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 1          15634602    Hargrave    619          France     Female  42   2       0.00       1              1          1               101348.88        1         1
# 6671       15667932    Bellucci    758          Spain      Female  43   10      0.00       2              1          1               55313.44         0         1
# 6664       15766185    She         850          Germany    Male    31   4       146587.30  1              1          1               89874.82         0         1
# 6665       15667632    Birdseye    703          France     Female  42   7       0.00       2              0          1               72500.68         0         1
# 6666       15599024    Hope        506          Spain      Male    32   8       0.00       2              0          1               182692.80        0         1
#                                                                                                                                                                ..
# 3334       15599078    Yang        619          Germany    Female  41   5       92467.58   1              1          0               38270.47         0         1
# 3335       15702300    Walker      671          France     Male    27   5       0.00       2              0          0               120893.07        0         1
# 3336       15660735    T'ang       581          Spain      Female  31   6       0.00       2              1          0               188377.21        0         1
# 3337       15671390    Chukwukere  690          Spain      Male    36   10      0.00       2              1          0               55902.93         0         1
# 10000      15628319    Walker      792          France     Female  28   4       130142.79  1              1          0               38190.78         0         1
# Name: count, Length: 10000, dtype: int64

# %% [markdown]
# ## Checking Null Values

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# * Cleaned data

# %%
df.copy()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# ## Checking datatypes of columns

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# ## Display object datatypes

# %%
df.select_dtypes('object')
# Out:
#         Surname Geography  Gender
# 0      Hargrave    France  Female
# 1          Hill     Spain  Female
# 2          Onio    France  Female
# 3          Boni    France  Female
# 4      Mitchell     Spain  Female
# ...         ...       ...     ...
# 9995   Obijiaku    France    Male
# 9996  Johnstone    France    Male
# 9997        Liu    France  Female
# 9998  Sabbatini   Germany    Male
# 9999     Walker    France  Female
#
# [10000 rows x 3 columns]

# %% [markdown]
# ## Display Numerical Features

# %%
df.select_dtypes(['int64','float64'])
# Out:
#       RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602          619   42       2       0.00
# 1             2    15647311          608   41       1   83807.86
# 2             3    15619304          502   42       8  159660.80
# 3             4    15701354          699   39       1       0.00
# 4             5    15737888          850   43       2  125510.82
# ...         ...         ...          ...  ...     ...        ...
# 9995       9996    15606229          771   39       5       0.00
# 9996       9997    15569892          516   35      10   57369.61
# 9997       9998    15584532          709   36       7       0.00
# 9998       9999    15682355          772   42       3   75075.31
# 9999      10000    15628319          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                 1          1               1        101348.88       1
# 1                 1          0               1        112542.58       0
# 2                 3          1               0        113931.57       1
# 3                 2          0               0         93826.63       0
# 4                 1          1               1         79084.10       0
# ...             ...        ...             ...              ...     ...
# 9995              2          1               0         96270.64       0
# 9996              1          1               1        101699.77       0
# 9997              1          0               1         42085.58       1
# 9998              2          1               0         92888.52       1
# 9999              1          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %% [markdown]
# ## Checking Duplicates

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * No duplicate values

# %% [markdown]
# # Convert Data Types

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Balance']=df['Balance'].astype(int)
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance              int64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# # Feature Engineering

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df[['Balance','Tenure']]
# Out:
#       Balance  Tenure
# 0           0       2
# 1       83807       1
# 2      159660       8
# 3           0       1
# 4      125510       2
# ...       ...     ...
# 9995        0       5
# 9996    57369      10
# 9997        0       7
# 9998    75075       3
# 9999   130142       4
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## What is the average balance per year of tenure for each customer?

# %%
df['Balance per year of tenure']=df['Balance']/df['Tenure']

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2        0              1          1               1
# 1          1    83807              1          0               1
# 2          8   159660              3          1               0
# 3          1        0              2          0               0
# 4          2   125510              1          1               1
# ...      ...      ...            ...        ...             ...
# 9995       5        0              2          1               0
# 9996      10    57369              1          1               1
# 9997       7        0              1          0               1
# 9998       3    75075              2          1               0
# 9999       4   130142              1          1               0
#
#       EstimatedSalary  Exited  Balance per year of tenure
# 0           101348.88       1                         0.0
# 1           112542.58       0                     83807.0
# 2           113931.57       1                     19957.5
# 3            93826.63       0                         0.0
# 4            79084.10       0                     62755.0
# ...               ...     ...                         ...
# 9995         96270.64       0                         0.0
# 9996        101699.77       0                      5736.9
# 9997         42085.58       1                         0.0
# 9998         92888.52       1                     25025.0
# 9999         38190.78       0                     32535.5
#
# [10000 rows x 15 columns]

# %%
df[['Tenure','EstimatedSalary']]
# Out:
#       Tenure  EstimatedSalary
# 0          2        101348.88
# 1          1        112542.58
# 2          8        113931.57
# 3          1         93826.63
# 4          2         79084.10
# ...      ...              ...
# 9995       5         96270.64
# 9996      10        101699.77
# 9997       7         42085.58
# 9998       3         92888.52
# 9999       4         38190.78
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## Group customers into age categories such as Young, Middle-aged, and Senior.

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 30, 60, 100], labels=['Young', 'Middle-aged', 'Senior'])

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       2        0              1          1               1        101348.88
# 1       1    83807              1          0               1        112542.58
# 2       8   159660              3          1               0        113931.57
# 3       1        0              2          0               0         93826.63
# 4       2   125510              1          1               1         79084.10
#
#    Exited  Balance per year of tenure     AgeGroup
# 0       1                         0.0  Middle-aged
# 1       0                     83807.0  Middle-aged
# 2       1                     19957.5  Middle-aged
# 3       0                         0.0  Middle-aged
# 4       0                     62755.0  Middle-aged

# %% [markdown]
# ## Calculate the ratio of the customer’s balance to their estimated salary.

# %%
df['Balance_to_salary_ratio']=df['Balance']/df['EstimatedSalary']

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       2        0              1          1               1        101348.88
# 1       1    83807              1          0               1        112542.58
# 2       8   159660              3          1               0        113931.57
# 3       1        0              2          0               0         93826.63
# 4       2   125510              1          1               1         79084.10
#
#    Exited  Balance per year of tenure     AgeGroup  Balance_to_salary_ratio
# 0       1                         0.0  Middle-aged                 0.000000
# 1       0                     83807.0  Middle-aged                 0.744669
# 2       1                     19957.5  Middle-aged                 1.401368
# 3       0                         0.0  Middle-aged                 0.000000
# 4       0                     62755.0  Middle-aged                 1.587045

# %% [markdown]
# ## Create a Loyalty Score Based on Tenure and Number of Products

# %%
df['LoyaltyScore']=df['Tenure']*df['NumOfProducts']

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       2        0              1          1               1        101348.88
# 1       1    83807              1          0               1        112542.58
# 2       8   159660              3          1               0        113931.57
# 3       1        0              2          0               0         93826.63
# 4       2   125510              1          1               1         79084.10
#
#    Exited  Balance per year of tenure     AgeGroup  Balance_to_salary_ratio  \
# 0       1                         0.0  Middle-aged                 0.000000
# 1       0                     83807.0  Middle-aged                 0.744669
# 2       1                     19957.5  Middle-aged                 1.401368
# 3       0                         0.0  Middle-aged                 0.000000
# 4       0                     62755.0  Middle-aged                 1.587045
#
#    LoyaltyScore
# 0             2
# 1             1
# 2            24
# 3             2
# 4             2

# %% [markdown]
# ## Categorize CreditScore into risk levels such as Low, Medium, and High.

# %%
df['CreditRisk']=pd.cut(df['CreditScore'],bins=[300,600,800,1000],labels=['Low','Medium','High'])

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       2        0              1          1               1        101348.88
# 1       1    83807              1          0               1        112542.58
# 2       8   159660              3          1               0        113931.57
# 3       1        0              2          0               0         93826.63
# 4       2   125510              1          1               1         79084.10
#
#    Exited  Balance per year of tenure     AgeGroup  Balance_to_salary_ratio  \
# 0       1                         0.0  Middle-aged                 0.000000
# 1       0                     83807.0  Middle-aged                 0.744669
# 2       1                     19957.5  Middle-aged                 1.401368
# 3       0                         0.0  Middle-aged                 0.000000
# 4       0                     62755.0  Middle-aged                 1.587045
#
#    LoyaltyScore CreditRisk
# 0             2     Medium
# 1             1     Medium
# 2            24        Low
# 3             2     Medium
# 4             2       High

# %% [markdown]
# ## Create a new feature that combines IsActiveMember and HasCrCard.

# %%
df['Active_member']=df['IsActiveMember']*df['HasCrCard']

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure  Balance  NumOfProducts  ...  IsActiveMember  EstimatedSalary  \
# 0       2        0              1  ...               1        101348.88
# 1       1    83807              1  ...               1        112542.58
# 2       8   159660              3  ...               0        113931.57
# 3       1        0              2  ...               0         93826.63
# 4       2   125510              1  ...               1         79084.10
#
#    Exited  Balance per year of tenure     AgeGroup Balance_to_salary_ratio  \
# 0       1                         0.0  Middle-aged                0.000000
# 1       0                     83807.0  Middle-aged                0.744669
# 2       1                     19957.5  Middle-aged                1.401368
# 3       0                         0.0  Middle-aged                0.000000
# 4       0                     62755.0  Middle-aged                1.587045
#
#    LoyaltyScore  CreditRisk Active_member  DaysSinceJoining
# 0             2      Medium             1               730
# 1             1      Medium             0               365
# 2            24         Low             0              2920
# 3             2      Medium             0               365
# 4             2        High             1               730
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Calculate the total number of days since the customer joined based on their tenure.

# %%
df['DaysSinceJoining'] = df['Tenure'] * 365

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure  Balance  NumOfProducts  ...  IsActiveMember  EstimatedSalary  \
# 0       2        0              1  ...               1        101348.88
# 1       1    83807              1  ...               1        112542.58
# 2       8   159660              3  ...               0        113931.57
# 3       1        0              2  ...               0         93826.63
# 4       2   125510              1  ...               1         79084.10
#
#    Exited  Balance per year of tenure     AgeGroup Balance_to_salary_ratio  \
# 0       1                         0.0  Middle-aged                0.000000
# 1       0                     83807.0  Middle-aged                0.744669
# 2       1                     19957.5  Middle-aged                1.401368
# 3       0                         0.0  Middle-aged                0.000000
# 4       0                     62755.0  Middle-aged                1.587045
#
#    LoyaltyScore  CreditRisk Active_member  DaysSinceJoining
# 0             2      Medium             1               730
# 1             1      Medium             0               365
# 2            24         Low             0              2920
# 3             2      Medium             0               365
# 4             2        High             1               730
#
# [5 rows x 21 columns]

# %% [markdown]
# # Sorting

# %% [markdown]
# ## Identify the most loyal customers by sorting the data based on the Tenure column in descending order.

# %%
df_sorted_by_tenure=df.sort_values(by='Tenure',ascending=False)

# %%
df_sorted_by_tenure
# Out:
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender  \
# 7565       7566    15623369         Clifton          708    France    Male
# 9302       9303    15752534         Mironov          744    France    Male
# 376         377    15583456        Gardiner          745   Germany    Male
# 7596       7597    15794868          Nnonso          599   Germany    Male
# 6827       6828    15760216     Pokrovskaya          718    France  Female
# ...         ...         ...             ...          ...       ...     ...
# 5150       5151    15614716  Okwudilichukwu          515    France  Female
# 1685       1686    15713826        Ferguson          613   Germany  Female
# 1682       1683    15662758          Watson          620    France    Male
# 8869       8870    15733597            Y?an          669    France  Female
# 6734       6735    15723318         Mactier          619    France  Female
#
#       Age  Tenure  Balance  NumOfProducts  ...  IsActiveMember  \
# 7565   52      10   105355              1  ...               0
# 9302   36      10        0              2  ...               1
# 376    45      10   117231              3  ...               1
# 7596   40      10   137456              2  ...               1
# 6827   49      10        0              1  ...               0
# ...   ...     ...      ...            ...  ...             ...
# 5150   37       0   196853              1  ...               1
# 1685   20       0   117356              1  ...               0
# 1682   41       0    97925              1  ...               0
# 8869   41       0   150219              2  ...               0
# 6734   55       0        0              3  ...               0
#
#       EstimatedSalary  Exited  Balance per year of tenure     AgeGroup  \
# 7565           123.07       1                     10535.5  Middle-aged
# 9302        182867.84       0                         0.0  Middle-aged
# 376         122381.02       1                     11723.1  Middle-aged
# 7596         14113.11       0                     13745.6  Middle-aged
# 6827        184474.72       1                         0.0  Middle-aged
# ...               ...     ...                         ...          ...
# 5150        132770.11       0                         inf  Middle-aged
# 1685        113557.70       1                         inf        Young
# 1682         85000.32       0                         inf  Middle-aged
# 8869        107839.03       0                         inf  Middle-aged
# 6734         60810.64       1                         NaN  Middle-aged
#
#      Balance_to_salary_ratio  LoyaltyScore  CreditRisk Active_member  \
# 7565              856.057528            10      Medium             0
# 9302                0.000000            20      Medium             1
# 376                 0.957918            30      Medium             1
# 7596                9.739597            20         Low             1
# 6827                0.000000            10      Medium             0
# ...                      ...           ...         ...           ...
# 5150                1.482661             0         Low             1
# 1685                1.033448             0      Medium             0
# 1682                1.152054             0      Medium             0
# 8869                1.392993             0      Medium             0
# 6734                0.000000             0      Medium             0
#
#       DaysSinceJoining
# 7565              3650
# 9302              3650
# 376               3650
# 7596              3650
# 6827              3650
# ...                ...
# 5150                 0
# 1685                 0
# 1682                 0
# 8869                 0
# 6734                 0
#
# [10000 rows x 21 columns]

# %% [markdown]
# ## Find customers with the highest creditworthiness and account balance by sorting first by CreditScore and then by Balance.

# %%
df_sorted=df.sort_values(by=['CreditScore','Balance'],ascending=[False,False])

# %%
df_sorted.head()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 1533       1534    15769818      Moore          850    France  Female   37
# 520         521    15671256  Macartney          850    France  Female   35
# 4533       4534    15607275     Ch'ang          850     Spain    Male   39
# 4167       4168    15737509   Morrison          850     Spain    Male   34
# 4674       4675    15689492   Benjamin          850   Germany    Male   41
#
#       Tenure  Balance  NumOfProducts  ...  IsActiveMember  EstimatedSalary  \
# 1533       3   212778              1  ...               1         69372.88
# 520        1   211774              1  ...               0        188574.12
# 4533       6   206014              2  ...               1         42774.84
# 4167       8   199229              1  ...               0         68106.29
# 4674       1   176958              2  ...               1        125806.30
#
#       Exited  Balance per year of tenure     AgeGroup Balance_to_salary_ratio  \
# 1533       0                70926.000000  Middle-aged                3.067164
# 520        1               211774.000000  Middle-aged                1.123028
# 4533       1                34335.666667  Middle-aged                4.816242
# 4167       0                24903.625000  Middle-aged                2.925266
# 4674       0               176958.000000  Middle-aged                1.406591
#
#       LoyaltyScore  CreditRisk Active_member  DaysSinceJoining
# 1533             3        High             0              1095
# 520              1        High             0               365
# 4533            12        High             0              2190
# 4167             8        High             0              2920
# 4674             2        High             0               365
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Sort by Balance and HasCrCard to Identify High-Balance Customers with Credit Cards

# %%
sorted_by_balance_card = df.sort_values(by=['Balance', 'HasCrCard'], ascending=[False, False])

# %%
sorted_by_balance_card.head()
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 2092       2093    15757408        Lo          655     Spain    Male   38
# 3280       3281    15715622    To Rot          583    France  Female   57
# 8733       8734    15714241    Haddon          749     Spain    Male   42
# 3588       3589    15571958  McIntosh          489     Spain    Male   40
# 6717       6718    15586674      Shaw          663     Spain  Female   58
#
#       Tenure  Balance  NumOfProducts  ...  IsActiveMember  EstimatedSalary  \
# 2092       3   250898              3  ...               1         81054.00
# 3280       3   238387              1  ...               1        147964.99
# 8733       9   222267              1  ...               0        101108.85
# 3588       3   221532              1  ...               0        171867.08
# 6717       5   216109              1  ...               1         74176.71
#
#       Exited  Balance per year of tenure     AgeGroup Balance_to_salary_ratio  \
# 2092       1                83632.666667  Middle-aged                3.095443
# 3280       1                79462.333333  Middle-aged                1.611104
# 8733       1                24696.333333  Middle-aged                2.198294
# 3588       0                73844.000000  Middle-aged                1.288973
# 6717       1                43221.800000  Middle-aged                2.913435
#
#       LoyaltyScore  CreditRisk Active_member  DaysSinceJoining
# 2092             9      Medium             0              1095
# 3280             3         Low             0              1095
# 8733             9      Medium             0              3285
# 3588             3         Low             0              1095
# 6717             5      Medium             0              1825
#
# [5 rows x 21 columns]

# %% [markdown]
# ## value_counts

# %% [markdown]
# ## What is the distribution of customers across different AgeGroup categories?

# %%
df['AgeGroup'].value_counts()
# Out:
# AgeGroup
# Middle-aged    7568
# Young          1968
# Senior          464
# Name: count, dtype: int64

# %% [markdown]
# ## What is the distribution of customers across different credit risk categories?

# %%
df['CreditRisk'].value_counts()
# Out:
# CreditRisk
# Medium    6289
# Low       3066
# High       645
# Name: count, dtype: int64

# %% [markdown]
# ## What is the average account balance for each age group?

# %%
df.groupby('AgeGroup')['Balance'].mean()
# Out:
# <ipython-input-55-d827ca7b4c64>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('AgeGroup')['Balance'].mean()
# AgeGroup
# Young          73198.463923
# Middle-aged    77385.930233
# Senior         75742.280172
# Name: Balance, dtype: float64

# %% [markdown]
# ## What is the distribution of customers across different geographies?

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %% [markdown]
# ## What is the average balance of customers across different geographies and age groups?

# %%
df.groupby(['Geography','AgeGroup'])['Balance'].mean()
# Out:
# <ipython-input-59-aba25dafeb59>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Geography','AgeGroup'])['Balance'].mean()
# Geography  AgeGroup
# France     Young           59631.646435
#            Middle-aged     62913.012550
#            Senior          59845.450216
# Germany    Young          119186.476821
#            Middle-aged    119860.744210
#            Senior         119652.309735
# Spain      Young           59047.073375
#            Middle-aged     62318.118085
#            Senior          64995.066667
# Name: Balance, dtype: float64
