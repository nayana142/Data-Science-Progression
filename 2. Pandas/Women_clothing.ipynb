# %% [markdown]
# ## Import library

# %%
import pandas as pd

# %%
data=pd.read_csv('women_clothing.csv')

# %% [markdown]
# ## Data Description
# * order_id: Unique identifier for each order (integer).
# * order_date: The date on which the order was placed (string).
# * sku: Stock Keeping Unit, which uniquely identifies each product or item (string).
# * color: The color attribute of the product (string).
# * size: The size of the product (string).
# * unit_price: The price per unit of the product (integer).
# * quantity: The number of units ordered (integer).
# * revenue: The total revenue generated from the order (integer).

# %%
data
# Out:
#      order_id          order_date   sku      color      size  unit_price  \
# 0           1   2022/6/1 16:05:00   708  Dark Blue       2XL         298
# 1           1   2022/6/1 16:05:00    89  Dark Blue       2XL         258
# 2           2  2022/6/10 17:03:00  bobo      Cream  One Size         228
# 3           3  2022/6/10 19:59:00   799  Dark Blue        XL         264
# 4           4  2022/6/11 11:42:00   799  Dark Blue         M         264
# ..        ...                 ...   ...        ...       ...         ...
# 522       171    2022/9/9 6:27:00   799  Dark Blue         M         265
# 523       172    2022/9/9 7:18:00   708  Dark Blue       4XL         278
# 524       173    2022/9/9 7:22:00   799  Dark Blue         M         265
# 525       174    2022/9/9 8:25:00   799  Dark Blue         L         265
# 526       175    2022/9/9 9:47:00   799  Dark Blue        XL         265
#
#      quantity  revenue
# 0           1      298
# 1           1      258
# ...

# %%
# printing first 5 rows

# %%
data.head()
# Out:
#    order_id          order_date   sku      color      size  unit_price  \
# 0         1   2022/6/1 16:05:00   708  Dark Blue       2XL         298
# 1         1   2022/6/1 16:05:00    89  Dark Blue       2XL         258
# 2         2  2022/6/10 17:03:00  bobo      Cream  One Size         228
# 3         3  2022/6/10 19:59:00   799  Dark Blue        XL         264
# 4         4  2022/6/11 11:42:00   799  Dark Blue         M         264
#
#    quantity  revenue
# 0         1      298
# 1         1      258
# 2         1      228
# 3         1      264
# 4         1      264

# %%
# printing first 20 rows

# %%
data.head(20)
# Out:
#     order_id          order_date   sku       color      size  unit_price  \
# 0          1   2022/6/1 16:05:00   708   Dark Blue       2XL         298
# 1          1   2022/6/1 16:05:00    89   Dark Blue       2XL         258
# 2          2  2022/6/10 17:03:00  bobo       Cream  One Size         228
# 3          3  2022/6/10 19:59:00   799   Dark Blue        XL         264
# 4          4  2022/6/11 11:42:00   799   Dark Blue         M         264
# 5          5  2022/6/11 14:46:00   799   Dark Blue        XL         264
# 6          6  2022/6/11 19:23:00   799   Dark Blue        XL         264
# 7          7  2022/6/11 19:54:00   708   Dark Blue       3XL         278
# 8          8  2022/6/11 21:09:00   708   Dark Blue        XL         278
# 9          9  2022/6/11 22:53:00   239       Black       NaN         258
# 10        10  2022/6/12 17:32:00   708   Dark Blue        XL         278
# 11        11  2022/6/12 21:16:00   708   Dark Blue       3XL         278
# ...

# %%
# printing last 5 rows

# %%
data.tail()
# Out:
#      order_id        order_date  sku      color size  unit_price  quantity  \
# 522       171  2022/9/9 6:27:00  799  Dark Blue    M         265         1
# 523       172  2022/9/9 7:18:00  708  Dark Blue  4XL         278         1
# 524       173  2022/9/9 7:22:00  799  Dark Blue    M         265         1
# 525       174  2022/9/9 8:25:00  799  Dark Blue    L         265         1
# 526       175  2022/9/9 9:47:00  799  Dark Blue   XL         265         1
#
#      revenue
# 522      265
# 523      278
# 524      265
# 525      265
# 526      265

# %%
# to display shape

# %%
data.shape
# Out:
# (527, 8)

# %%
data.size
# Out:
# 4216

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527 entries, 0 to 526
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    527 non-null    int64
#  1   order_date  527 non-null    object
#  2   sku         527 non-null    object
#  3   color       527 non-null    object
#  4   size        490 non-null    object
#  5   unit_price  527 non-null    int64
#  6   quantity    527 non-null    int64
#  7   revenue     527 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 33.1+ KB

# %%
data.describe()
# Out:
#          order_id  unit_price    quantity     revenue
# count  527.000000  527.000000  527.000000  527.000000
# mean   115.313093  274.973435    1.011385  278.024668
# std     73.106716   34.517412    0.106193   44.741095
# min      1.000000  191.000000    1.000000  191.000000
# 25%     54.000000  266.000000    1.000000  266.000000
# 50%    110.000000  278.000000    1.000000  278.000000
# 75%    166.000000  288.000000    1.000000  288.000000
# max    273.000000  899.000000    2.000000  899.000000

# %%
data.describe(include='O')
# Out:
#                order_date  sku      color size
# count                 527  527        527  490
# unique                444   24         39    9
# top     2022/9/4 14:51:00  799  Dark Blue   XL
# freq                   12  283        397  164

# %%
data.describe(include='all')
# Out:
#           order_id         order_date  sku      color size  unit_price  \
# count   527.000000                527  527        527  490  527.000000
# unique         NaN                444   24         39    9         NaN
# top            NaN  2022/9/4 14:51:00  799  Dark Blue   XL         NaN
# freq           NaN                 12  283        397  164         NaN
# mean    115.313093                NaN  NaN        NaN  NaN  274.973435
# std      73.106716                NaN  NaN        NaN  NaN   34.517412
# min       1.000000                NaN  NaN        NaN  NaN  191.000000
# 25%      54.000000                NaN  NaN        NaN  NaN  266.000000
# 50%     110.000000                NaN  NaN        NaN  NaN  278.000000
# 75%     166.000000                NaN  NaN        NaN  NaN  288.000000
# max     273.000000                NaN  NaN        NaN  NaN  899.000000
#
#           quantity     revenue
# count   527.000000  527.000000
# unique         NaN         NaN
# ...

# %%
data
# Out:
#      order_id          order_date   sku      color      size  unit_price  \
# 0           1   2022/6/1 16:05:00   708  Dark Blue       2XL         298
# 1           1   2022/6/1 16:05:00    89  Dark Blue       2XL         258
# 2           2  2022/6/10 17:03:00  bobo      Cream  One Size         228
# 3           3  2022/6/10 19:59:00   799  Dark Blue        XL         264
# 4           4  2022/6/11 11:42:00   799  Dark Blue         M         264
# ..        ...                 ...   ...        ...       ...         ...
# 522       171    2022/9/9 6:27:00   799  Dark Blue         M         265
# 523       172    2022/9/9 7:18:00   708  Dark Blue       4XL         278
# 524       173    2022/9/9 7:22:00   799  Dark Blue         M         265
# 525       174    2022/9/9 8:25:00   799  Dark Blue         L         265
# 526       175    2022/9/9 9:47:00   799  Dark Blue        XL         265
#
#      quantity  revenue
# 0           1      298
# 1           1      258
# ...

# %%
data.columns
# Out:
# Index(['order_id', 'order_date', 'sku', 'color', 'size', 'unit_price',
#        'quantity', 'revenue'],
#       dtype='object')

# %%
data
# Out:
#      order_id          order_date   sku      color      size  unit_price  \
# 0           1   2022/6/1 16:05:00   708  Dark Blue       2XL         298
# 1           1   2022/6/1 16:05:00    89  Dark Blue       2XL         258
# 2           2  2022/6/10 17:03:00  bobo      Cream  One Size         228
# 3           3  2022/6/10 19:59:00   799  Dark Blue        XL         264
# 4           4  2022/6/11 11:42:00   799  Dark Blue         M         264
# ..        ...                 ...   ...        ...       ...         ...
# 522       171    2022/9/9 6:27:00   799  Dark Blue         M         265
# 523       172    2022/9/9 7:18:00   708  Dark Blue       4XL         278
# 524       173    2022/9/9 7:22:00   799  Dark Blue         M         265
# 525       174    2022/9/9 8:25:00   799  Dark Blue         L         265
# 526       175    2022/9/9 9:47:00   799  Dark Blue        XL         265
#
#      quantity  revenue
# 0           1      298
# 1           1      258
# ...

# %%
data['order_date']
# Out:
# 0       2022/6/1 16:05:00
# 1       2022/6/1 16:05:00
# 2      2022/6/10 17:03:00
# 3      2022/6/10 19:59:00
# 4      2022/6/11 11:42:00
#               ...
# 522      2022/9/9 6:27:00
# 523      2022/9/9 7:18:00
# 524      2022/9/9 7:22:00
# 525      2022/9/9 8:25:00
# 526      2022/9/9 9:47:00
# Name: order_date, Length: 527, dtype: object

# %%
data.order_date
# Out:
# 0       2022/6/1 16:05:00
# 1       2022/6/1 16:05:00
# 2      2022/6/10 17:03:00
# 3      2022/6/10 19:59:00
# 4      2022/6/11 11:42:00
#               ...
# 522      2022/9/9 6:27:00
# 523      2022/9/9 7:18:00
# 524      2022/9/9 7:22:00
# 525      2022/9/9 8:25:00
# 526      2022/9/9 9:47:00
# Name: order_date, Length: 527, dtype: object

# %%
data[['order_date','revenue']]
# Out:
#              order_date  revenue
# 0     2022/6/1 16:05:00      298
# 1     2022/6/1 16:05:00      258
# 2    2022/6/10 17:03:00      228
# 3    2022/6/10 19:59:00      264
# 4    2022/6/11 11:42:00      264
# ..                  ...      ...
# 522    2022/9/9 6:27:00      265
# 523    2022/9/9 7:18:00      278
# 524    2022/9/9 7:22:00      265
# 525    2022/9/9 8:25:00      265
# 526    2022/9/9 9:47:00      265
#
# [527 rows x 2 columns]

# %% [markdown]
# # loc

# %%
data.loc[0:14,:]
# Out:
#     order_id          order_date   sku      color      size  unit_price  \
# 0          1   2022/6/1 16:05:00   708  Dark Blue       2XL         298
# 1          1   2022/6/1 16:05:00    89  Dark Blue       2XL         258
# 2          2  2022/6/10 17:03:00  bobo      Cream  One Size         228
# 3          3  2022/6/10 19:59:00   799  Dark Blue        XL         264
# 4          4  2022/6/11 11:42:00   799  Dark Blue         M         264
# 5          5  2022/6/11 14:46:00   799  Dark Blue        XL         264
# 6          6  2022/6/11 19:23:00   799  Dark Blue        XL         264
# 7          7  2022/6/11 19:54:00   708  Dark Blue       3XL         278
# 8          8  2022/6/11 21:09:00   708  Dark Blue        XL         278
# 9          9  2022/6/11 22:53:00   239      Black       NaN         258
# 10        10  2022/6/12 17:32:00   708  Dark Blue        XL         278
# 11        11  2022/6/12 21:16:00   708  Dark Blue       3XL         278
# ...

# %%
data.loc[0:14,'order_id': 'size']
# Out:
#     order_id          order_date   sku      color      size
# 0          1   2022/6/1 16:05:00   708  Dark Blue       2XL
# 1          1   2022/6/1 16:05:00    89  Dark Blue       2XL
# 2          2  2022/6/10 17:03:00  bobo      Cream  One Size
# 3          3  2022/6/10 19:59:00   799  Dark Blue        XL
# 4          4  2022/6/11 11:42:00   799  Dark Blue         M
# 5          5  2022/6/11 14:46:00   799  Dark Blue        XL
# 6          6  2022/6/11 19:23:00   799  Dark Blue        XL
# 7          7  2022/6/11 19:54:00   708  Dark Blue       3XL
# 8          8  2022/6/11 21:09:00   708  Dark Blue        XL
# 9          9  2022/6/11 22:53:00   239      Black       NaN
# 10        10  2022/6/12 17:32:00   708  Dark Blue        XL
# 11        11  2022/6/12 21:16:00   708  Dark Blue       3XL
# 12        12   2022/6/12 8:47:00   708  Dark Blue       3XL
# 13        13  2022/6/13 10:11:00   799  Dark Blue        XL
# 14        14   2022/6/14 0:07:00   799  Dark Blue         M

# %%
data.loc[0:14,['order_id','size']]
# Out:
#     order_id      size
# 0          1       2XL
# 1          1       2XL
# 2          2  One Size
# 3          3        XL
# 4          4         M
# 5          5        XL
# 6          6        XL
# 7          7       3XL
# 8          8        XL
# 9          9       NaN
# 10        10        XL
# 11        11       3XL
# 12        12       3XL
# 13        13        XL
# 14        14         M

# %% [markdown]
# # iloc

# %%
data.iloc[:,2:5]
# Out:
#       sku      color      size
# 0     708  Dark Blue       2XL
# 1      89  Dark Blue       2XL
# 2    bobo      Cream  One Size
# 3     799  Dark Blue        XL
# 4     799  Dark Blue         M
# ..    ...        ...       ...
# 522   799  Dark Blue         M
# 523   708  Dark Blue       4XL
# 524   799  Dark Blue         M
# 525   799  Dark Blue         L
# 526   799  Dark Blue        XL
#
# [527 rows x 3 columns]

# %%
data.iloc[500:,3:6]
# Out:
#           color      size  unit_price
# 500   Dark Blue       3XL         298
# 501   Dark Blue        XL         288
# 502   Dark Blue         L         288
# 503   Dark Blue         L         288
# 504   Dark Blue         M         288
# 505   Dark Blue         M         265
# 506  Light Blue         L         238
# 507   Dark Blue         M         265
# 508   Dark Blue         L         265
# 509       Black  One Size         268
# 510   Dark Blue       3XL         278
# 511   Dark Blue       4XL         278
# 512   Dark Blue        XL         265
# 513   Dark Blue         M         265
# 514   Dark Blue         L         265
# 515   Dark Blue       2XL         278
# 516   Dark Blue        XL         265
# 517       White  One Size         228
# 518   Dark Blue       3XL         278
# 519   Dark Blue        XL         265
# 520   Dark Blue         M         265
# 521   Dark Blue         M         265
# 522   Dark Blue         M         265
# 523   Dark Blue       4XL         278
# ...

# %%
# copy()

# %%
df=data.copy()
df
# Out:
#      order_id          order_date   sku      color      size  unit_price  \
# 0           1   2022/6/1 16:05:00   708  Dark Blue       2XL         298
# 1           1   2022/6/1 16:05:00    89  Dark Blue       2XL         258
# 2           2  2022/6/10 17:03:00  bobo      Cream  One Size         228
# 3           3  2022/6/10 19:59:00   799  Dark Blue        XL         264
# 4           4  2022/6/11 11:42:00   799  Dark Blue         M         264
# ..        ...                 ...   ...        ...       ...         ...
# 522       171    2022/9/9 6:27:00   799  Dark Blue         M         265
# 523       172    2022/9/9 7:18:00   708  Dark Blue       4XL         278
# 524       173    2022/9/9 7:22:00   799  Dark Blue         M         265
# 525       174    2022/9/9 8:25:00   799  Dark Blue         L         265
# 526       175    2022/9/9 9:47:00   799  Dark Blue        XL         265
#
#      quantity  revenue
# 0           1      298
# 1           1      258
# ...

# %%
# pop()

# %%
d=df.pop('color')

# %%
d
# Out:
# 0      Dark Blue
# 1      Dark Blue
# 2          Cream
# 3      Dark Blue
# 4      Dark Blue
#          ...
# 522    Dark Blue
# 523    Dark Blue
# 524    Dark Blue
# 525    Dark Blue
# 526    Dark Blue
# Name: color, Length: 527, dtype: object

# %%
data
# Out:
#      order_id          order_date   sku      color      size  unit_price  \
# 0           1   2022/6/1 16:05:00   708  Dark Blue       2XL         298
# 1           1   2022/6/1 16:05:00    89  Dark Blue       2XL         258
# 2           2  2022/6/10 17:03:00  bobo      Cream  One Size         228
# 3           3  2022/6/10 19:59:00   799  Dark Blue        XL         264
# 4           4  2022/6/11 11:42:00   799  Dark Blue         M         264
# ..        ...                 ...   ...        ...       ...         ...
# 522       171    2022/9/9 6:27:00   799  Dark Blue         M         265
# 523       172    2022/9/9 7:18:00   708  Dark Blue       4XL         278
# 524       173    2022/9/9 7:22:00   799  Dark Blue         M         265
# 525       174    2022/9/9 8:25:00   799  Dark Blue         L         265
# 526       175    2022/9/9 9:47:00   799  Dark Blue        XL         265
#
#      quantity  revenue
# 0           1      298
# 1           1      258
# ...

# %%
df
# Out:
#      order_id          order_date   sku      size  unit_price  quantity  \
# 0           1   2022/6/1 16:05:00   708       2XL         298         1
# 1           1   2022/6/1 16:05:00    89       2XL         258         1
# 2           2  2022/6/10 17:03:00  bobo  One Size         228         1
# 3           3  2022/6/10 19:59:00   799        XL         264         1
# 4           4  2022/6/11 11:42:00   799         M         264         1
# ..        ...                 ...   ...       ...         ...       ...
# 522       171    2022/9/9 6:27:00   799         M         265         1
# 523       172    2022/9/9 7:18:00   708       4XL         278         1
# 524       173    2022/9/9 7:22:00   799         M         265         1
# 525       174    2022/9/9 8:25:00   799         L         265         1
# 526       175    2022/9/9 9:47:00   799        XL         265         1
#
#      revenue
# 0        298
# 1        258
# 2        228
# 3        264
# 4        264
# ..       ...
# ...

# %%
data.columns
# Out:
# Index(['order_id', 'order_date', 'sku', 'color', 'size', 'unit_price',
#        'quantity', 'revenue'],
#       dtype='object')

# %%
# drop

# %%
df.drop(columns=['size'],axis=1)
# Out:
#      order_id          order_date   sku  unit_price  quantity  revenue
# 0           1   2022/6/1 16:05:00   708         298         1      298
# 1           1   2022/6/1 16:05:00    89         258         1      258
# 2           2  2022/6/10 17:03:00  bobo         228         1      228
# 3           3  2022/6/10 19:59:00   799         264         1      264
# 4           4  2022/6/11 11:42:00   799         264         1      264
# ..        ...                 ...   ...         ...       ...      ...
# 522       171    2022/9/9 6:27:00   799         265         1      265
# 523       172    2022/9/9 7:18:00   708         278         1      278
# 524       173    2022/9/9 7:22:00   799         265         1      265
# 525       174    2022/9/9 8:25:00   799         265         1      265
# 526       175    2022/9/9 9:47:00   799         265         1      265
#
# [527 rows x 6 columns]

# %%
df
# Out:
#      order_id          order_date   sku      size  unit_price  quantity  \
# 0           1   2022/6/1 16:05:00   708       2XL         298         1
# 1           1   2022/6/1 16:05:00    89       2XL         258         1
# 2           2  2022/6/10 17:03:00  bobo  One Size         228         1
# 3           3  2022/6/10 19:59:00   799        XL         264         1
# 4           4  2022/6/11 11:42:00   799         M         264         1
# ..        ...                 ...   ...       ...         ...       ...
# 522       171    2022/9/9 6:27:00   799         M         265         1
# 523       172    2022/9/9 7:18:00   708       4XL         278         1
# 524       173    2022/9/9 7:22:00   799         M         265         1
# 525       174    2022/9/9 8:25:00   799         L         265         1
# 526       175    2022/9/9 9:47:00   799        XL         265         1
#
#      revenue
# 0        298
# 1        258
# 2        228
# 3        264
# 4        264
# ..       ...
# ...

# %%
# Assigning to new variable

# %%
ds=df.drop(columns=['size'],axis=1)

# %%
ds
# Out:
#      order_id          order_date   sku  unit_price  quantity  revenue
# 0           1   2022/6/1 16:05:00   708         298         1      298
# 1           1   2022/6/1 16:05:00    89         258         1      258
# 2           2  2022/6/10 17:03:00  bobo         228         1      228
# 3           3  2022/6/10 19:59:00   799         264         1      264
# 4           4  2022/6/11 11:42:00   799         264         1      264
# ..        ...                 ...   ...         ...       ...      ...
# 522       171    2022/9/9 6:27:00   799         265         1      265
# 523       172    2022/9/9 7:18:00   708         278         1      278
# 524       173    2022/9/9 7:22:00   799         265         1      265
# 525       174    2022/9/9 8:25:00   799         265         1      265
# 526       175    2022/9/9 9:47:00   799         265         1      265
#
# [527 rows x 6 columns]

# %%
# inplace= True, for reflect change in original dataframe

# %%
df.drop(columns=['size'],axis=1,inplace= True)

# %%
df
# Out:
#      order_id          order_date   sku  unit_price  quantity  revenue
# 0           1   2022/6/1 16:05:00   708         298         1      298
# 1           1   2022/6/1 16:05:00    89         258         1      258
# 2           2  2022/6/10 17:03:00  bobo         228         1      228
# 3           3  2022/6/10 19:59:00   799         264         1      264
# 4           4  2022/6/11 11:42:00   799         264         1      264
# ..        ...                 ...   ...         ...       ...      ...
# 522       171    2022/9/9 6:27:00   799         265         1      265
# 523       172    2022/9/9 7:18:00   708         278         1      278
# 524       173    2022/9/9 7:22:00   799         265         1      265
# 525       174    2022/9/9 8:25:00   799         265         1      265
# 526       175    2022/9/9 9:47:00   799         265         1      265
#
# [527 rows x 6 columns]

# %%
# dtypes

# %%
data['size'].dtype
# Out:
# dtype('O')

# %%
data.select_dtypes('object')
# Out:
#              order_date   sku      color      size
# 0     2022/6/1 16:05:00   708  Dark Blue       2XL
# 1     2022/6/1 16:05:00    89  Dark Blue       2XL
# 2    2022/6/10 17:03:00  bobo      Cream  One Size
# 3    2022/6/10 19:59:00   799  Dark Blue        XL
# 4    2022/6/11 11:42:00   799  Dark Blue         M
# ..                  ...   ...        ...       ...
# 522    2022/9/9 6:27:00   799  Dark Blue         M
# 523    2022/9/9 7:18:00   708  Dark Blue       4XL
# 524    2022/9/9 7:22:00   799  Dark Blue         M
# 525    2022/9/9 8:25:00   799  Dark Blue         L
# 526    2022/9/9 9:47:00   799  Dark Blue        XL
#
# [527 rows x 4 columns]

# %%
data.select_dtypes('int64')
# Out:
#      order_id  unit_price  quantity  revenue
# 0           1         298         1      298
# 1           1         258         1      258
# 2           2         228         1      228
# 3           3         264         1      264
# 4           4         264         1      264
# ..        ...         ...       ...      ...
# 522       171         265         1      265
# 523       172         278         1      278
# 524       173         265         1      265
# 525       174         265         1      265
# 526       175         265         1      265
#
# [527 rows x 4 columns]

# %%
data
# Out:
#      order_id          order_date   sku      color      size  unit_price  \
# 0           1   2022/6/1 16:05:00   708  Dark Blue       2XL         298
# 1           1   2022/6/1 16:05:00    89  Dark Blue       2XL         258
# 2           2  2022/6/10 17:03:00  bobo      Cream  One Size         228
# 3           3  2022/6/10 19:59:00   799  Dark Blue        XL         264
# 4           4  2022/6/11 11:42:00   799  Dark Blue         M         264
# ..        ...                 ...   ...        ...       ...         ...
# 522       171    2022/9/9 6:27:00   799  Dark Blue         M         265
# 523       172    2022/9/9 7:18:00   708  Dark Blue       4XL         278
# 524       173    2022/9/9 7:22:00   799  Dark Blue         M         265
# 525       174    2022/9/9 8:25:00   799  Dark Blue         L         265
# 526       175    2022/9/9 9:47:00   799  Dark Blue        XL         265
#
#      quantity  revenue
# 0           1      298
# 1           1      258
# ...

# %%
data.nunique()
# Out:
# order_id      273
# order_date    444
# sku            24
# color          39
# size            9
# unit_price     35
# quantity        2
# revenue        38
# dtype: int64

# %%
data['color'].unique()
# Out:
# array(['Dark Blue', 'Cream', 'Black', 'Navy Blue', 'Blue', 'Light Gray',
#        'B', 'C', 'D', 'E', 'A', 'Mid Wash', 'Light Blue', 'Dark Wash',
#        'Thin Blue', 'Rust', 'Grey Wash', 'Thin Black', '922 Black',
#        '922 Army green', 'Gray Stripes', '920 Navy blue', 'Light Wash',
#        'Blue Stripes', 'Black Stripes', 'Green', 'White', 'Mustard',
#        'Brown', 'Matcha', 'Gray', 'Midnight Blue', 'Maroon', 'Mocha',
#        'Skintone', 'Cornflower Blue', 'Yellow', 'Pink', 'Red Orange'],
#       dtype=object)
