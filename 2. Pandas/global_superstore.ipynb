# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading data

# %% [markdown]
# Column Descriptions:
# * Row ID: Unique identifier for each row in the dataset.
# * Order ID:Unique identifier for each order placed.
# * Order Date: The date when the order was placed.
# * Ship Date: The date when the order was shipped.
# * Ship Mode: The mode of shipping selected for the order (e.g., *Standard Class, Second Class, First Class, Same Day).
# * Customer ID:Unique identifier for each customer.
# * Customer Name:The full name of the customer who placed the order.
# * Segment:The market segment to which the customer belongs (e.g., Consumer, Corporate, Home Office).
# * Postal Code:The postal code for the customer’s location. Note that this column has a significant number of missing values.
# * City: The city where the customer is located.
# * State:The state where the customer is located.
# * Country:The country where the customer is located.
# * Region:The region within the country where the customer is located (e.g., East, West, Central, South).
# * Market: The broader market category, possibly indicating global regions
# * Product ID: Unique identifier for each product.
# * Category:The high-level category to which the product belongs.
# * Sub-Category:The sub-category of the product .
# * Product Name:The name of the product.
# * Sales: The sales revenue generated from the product.
# * Quantity:The number of units of the product sold.
# * Discount: The discount applied to the product, expressed as a decimal (e.g., 0.2 for 20% off).
# * Profit: The profit made from the sale of the product.
# * Shipping Cost:The cost of shipping the order.
# * Order Priority: The priority level of the order (e.g., Low, Medium, High, Critical).

# %%
data=pd.read_excel('global_superstore.xlsx')

# %%
data
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %% [markdown]
# # Exploratory Data Info

# %%
data.head(10)
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 5   22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 6   30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08     First Class
# 7   31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18  Standard Class
# 8   40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 9   36258  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# ...

# %%
data.tail(10)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 51280   35112  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
# 51281    6039   MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
# 51282   24175    IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51283   24105   IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# ...

# %%
data.shape
# Out:
# (51290, 24)

# %%
data.size
# Out:
# 1230960

# %%
51290*24
# Out:
# 1230960

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %% [markdown]
# *   The dataset has 15 categorical columns (e.g., 'Order ID', 'Customer Name', 'Region') and 7 numerical columns (e.g., 'Sales', 'Quantity', 'Discount').
#
# *   Two datetime columns ('Order Date', 'Ship Date') are crucial for time-series analysis.
# * The 'Postal Code' column has a significant amount of missing
# data, with only 9,994 out of 51,290 entries being non-null. This means approximately 80% of the data is missing in this column.

# %%
data.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
data.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2014-05-11 21:26:49.155780608
# min        1.00000            2012-01-01 00:00:00
# 25%    12823.25000            2013-06-19 00:00:00
# 50%    25645.50000            2014-07-08 00:00:00
# 75%    38467.75000            2015-05-22 00:00:00
# max    51290.00000            2015-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2014-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2012-01-03 00:00:00   1040.000000      0.444000
# 25%              2013-06-23 00:00:00  23223.000000     30.758625
# 50%              2014-07-12 00:00:00  56430.500000     85.053000
# 75%              2015-05-26 00:00:00  90008.000000    251.053200
# ...

# %%
data.describe(include='all').T
# Out:
#                   count unique                       top   freq  \
# Row ID          51290.0    NaN                       NaN    NaN
# Order ID          51290  25728  CA-2015-SV20365140-42268     14
# Order Date        51290    NaN                       NaN    NaN
# Ship Date         51290    NaN                       NaN    NaN
# Ship Mode         51290      4            Standard Class  30775
# Customer ID       51290  17415              SV-203651406     26
# Customer Name     51290    796           Muhammed Yedwab    108
# Segment           51290      3                  Consumer  26518
# Postal Code      9994.0    NaN                       NaN    NaN
# City              51290   3650             New York City    915
# State             51290   1102                California   2001
# Country           51290    165             United States   9994
# Region            51290     23            Western Europe   5883
# Market            51290      5              Asia Pacific  14302
# ...

# %%
data.describe(include='object')
# Out:
#                         Order ID       Ship Mode   Customer ID  \
# count                      51290           51290         51290
# unique                     25728               4         17415
# top     CA-2015-SV20365140-42268  Standard Class  SV-203651406
# freq                          14           30775            26
#
#           Customer Name   Segment           City       State        Country  \
# count             51290     51290          51290       51290          51290
# unique              796         3           3650        1102            165
# top     Muhammed Yedwab  Consumer  New York City  California  United States
# freq                108     26518            915        2001           9994
#
#                 Region        Market   Product ID         Category  \
# count            51290         51290        51290            51290
# unique              23             5         3788                3
# ...

# %%
data.nunique()
# Out:
# Row ID            51290
# Order ID          25728
# Order Date         1430
# Ship Date          1464
# Ship Mode             4
# Customer ID       17415
# Customer Name       796
# Segment               3
# Postal Code         631
# City               3650
# State              1102
# Country             165
# Region               23
# Market                5
# Product ID         3788
# Category              3
# Sub-Category         17
# Product Name       3788
# Sales             27200
# Quantity             14
# Discount             29
# Profit            28234
# Shipping Cost     16753
# Order Priority        4
# dtype: int64

# %% [markdown]
# # Checking Duplicates

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Length: 51290, dtype: bool

# %%
data
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# How many times a specific customer ('Customer ID') has purchased the same product ('Product ID') more than once.

# %%
data.duplicated(subset=['Customer ID','Product ID']).sum()
# Out:
# 118

# %%
df1=data[data.duplicated(subset=['Customer ID','Product ID'])]

# %%
df1
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 143     31649  CA-2014-AB10060140-41884 2014-09-02 2014-09-04     First Class
# 2628    40081  US-2015-AS10630140-42081 2015-03-18 2015-03-24  Standard Class
# 4257    33490  CA-2014-AP10915140-41984 2014-12-11 2014-12-18  Standard Class
# 4892    10287   US-2014-DN1369018-41688 2014-02-18 2014-02-22  Standard Class
# 5091     2377   MX-2013-AG1090082-41398 2013-05-04 2013-05-09  Standard Class
# ...       ...                       ...        ...        ...             ...
# 50428   10001   US-2014-DP1300018-41909 2014-09-27 2014-10-01  Standard Class
# 50611      11   MX-2014-DP1300018-41909 2014-09-27 2014-10-01  Standard Class
# 50963   38356  CA-2014-WB21850140-41985 2014-12-12 2014-12-12        Same Day
# 51017   10091   US-2012-KT1646518-41017 2012-04-18 2012-04-24  Standard Class
# 51129   37507  CA-2015-YS21880140-42235 2015-08-19 2015-08-26  Standard Class
#
# ...

# %%
data
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
data.drop_duplicates(keep='first',inplace=True)

# %%
data_6 = { 'Name': ['Alice', 'Bob', 'Charlie', 'Alice', 'Eve', 'Alice'],
        'Age': [24, 27, 22, 24, 29, 24],
      'City': ['New York', 'Los Angeles', 'Chicago', 'New York', 'Chicago', 'New York'] }
df6=pd.DataFrame(data_6)

# %%
df6
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    Alice   24     New York
# 4      Eve   29      Chicago
# 5    Alice   24     New York

# %%
df6.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
df_F=df6.drop_duplicates(keep='first')

# %%
df_F
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago

# %%
df_L=df6.drop_duplicates(keep='last')

# %%
df_L
# Out:
#       Name  Age         City
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago
# 5    Alice   24     New York

# %%
df_=df6.drop_duplicates(keep=False)

# %%
df_
# Out:
#       Name  Age         City
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago

# %% [markdown]
# # Convert Data Types

# %%
data.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
data['Postal Code']=data['Postal Code'].astype(str)

# %%
data.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code               object
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %% [markdown]
# # Feature Engineering

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# ###  Create a new feature that represents the total value of each order

# %%
data[['Sales','Quantity']]
# Out:
#           Sales  Quantity
# 0       221.980         2
# 1      3709.395         9
# 2      5175.171         9
# 3      2892.510         5
# 4      2832.960         8
# ...         ...       ...
# 51285    65.100         5
# 51286    16.720         5
# 51287     8.560         2
# 51288    13.440         2
# 51289    61.380         3
#
# [51290 rows x 2 columns]

# %%
data['Total_Order_Value']=data['Sales']*data['Quantity']

# %%
data.head(5)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ...    Category Sub-Category                               Product Name  \
# ...

# %% [markdown]
# ### Create a feature that calculates the profit margin as a percentage of the total sales.

# %%
data['profit margin']=(data['Profit']/data['Sales'])*100

# %%
data.head(5)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Sub-Category                               Product Name     Sales  \
# ...

# %% [markdown]
# ### Create a feature that calculates the price of the product after applying the discount.

# %%
data['price_after_discount']=data['Sales']* (1-data['Discount'])

# %%
data.head(5)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ...                               Product Name     Sales Quantity Discount  \
# ...

# %% [markdown]
# ### Create a feature that represents the shipping cost per unit sold.

# %%
data['Shipping_cost_per_unit']=data['Shipping Cost']/data['Quantity']

# %% [markdown]
# # Extracting Date and Time Components
# * Extracting date and time components from datetime objects

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Row ID                  51290 non-null  int64
#  1   Order ID                51290 non-null  object
#  2   Order Date              51290 non-null  datetime64[ns]
#  3   Ship Date               51290 non-null  datetime64[ns]
#  4   Ship Mode               51290 non-null  object
#  5   Customer ID             51290 non-null  object
#  6   Customer Name           51290 non-null  object
#  7   Segment                 51290 non-null  object
#  8   Postal Code             51290 non-null  object
#  9   City                    51290 non-null  object
#  10  State                   51290 non-null  object
#  11  Country                 51290 non-null  object
#  12  Region                  51290 non-null  object
#  13  Market                  51290 non-null  object
# ...

# %% [markdown]
# ### Extract the year from the 'Order Date' to create a new feature indicating the year in which the order was placed.

# %%
data['order_year']=data['Order Date'].dt.year

# %%
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Quantity Discount    Profit Shipping Cost Order Priority  \
# ...

# %% [markdown]
# ### Extract the month from the 'Order Date' to create a new feature indicating the month in which the order was placed.

# %%
data['order_month']=data['Order Date'].dt.month
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Discount    Profit Shipping Cost Order Priority Total_Order_Value  \
# ...

# %%
data['order_month_name']=data['Order Date'].dt.month_name()
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ...    Profit Shipping Cost Order Priority Total_Order_Value profit margin  \
# ...

# %% [markdown]
# ### Day of the week on which the order was placed

# %%
data['order_day']=data['Order Date'].dt.day
data['order_day_name']=data['Order Date'].dt.day_name()
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Order Priority Total_Order_Value profit margin price_after_discount  \
# ...

# %%
# Sample data for more feature engineering

# %%
data1 = { 'Timestamp': ['2024-07-24 14:45:00', '2024-07-25 16:30:00',
                      '2024-07-26 08:20:00', '2024-07-27 12:15:00'] }
df = pd.DataFrame(data1)
df
# Out:
#              Timestamp
# 0  2024-07-24 14:45:00
# 1  2024-07-25 16:30:00
# 2  2024-07-26 08:20:00
# 3  2024-07-27 12:15:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  4 non-null      object
# dtypes: object(1)
# memory usage: 160.0+ bytes

# %%
# df['Timestamp']=(df['Timestamp']).astype('datetime64[ns]')
# df.info()

# %%
df['Timestamp']=pd.to_datetime(df['Timestamp'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 160.0 bytes

# %%
df
# Out:
#             Timestamp
# 0 2024-07-24 14:45:00
# 1 2024-07-25 16:30:00
# 2 2024-07-26 08:20:00
# 3 2024-07-27 12:15:00

# %%
df['date']=df['Timestamp'].dt.date
df['year']=df['Timestamp'].dt.year
df['month']=df['Timestamp'].dt.month
df['hour']=df['Timestamp'].dt.hour
df['minute']=df['Timestamp'].dt.minute
df['Seconds']=df['Timestamp'].dt.second
df
# Out:
#             Timestamp        date  year  month  hour  minute  Seconds
# 0 2024-07-24 14:45:00  2024-07-24  2024      7    14      45        0
# 1 2024-07-25 16:30:00  2024-07-25  2024      7    16      30        0
# 2 2024-07-26 08:20:00  2024-07-26  2024      7     8      20        0
# 3 2024-07-27 12:15:00  2024-07-27  2024      7    12      15        0

# %% [markdown]
# # date_range

# %%
ds=pd.date_range(start='2023-01-01',end='2023-12-31',freq='D')
ds
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10',
#                ...
#                '2023-12-22', '2023-12-23', '2023-12-24', '2023-12-25',
#                '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29',
#                '2023-12-30', '2023-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
ds=pd.date_range(start='2023-01-01',end='2023-12-31',freq='M')
ds
# Out:
# DatetimeIndex(['2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30',
#                '2023-05-31', '2023-06-30', '2023-07-31', '2023-08-31',
#                '2023-09-30', '2023-10-31', '2023-11-30', '2023-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ds=pd.date_range(start='2023-01-01',end='2023-12-31',periods=10)
ds
# Out:
# DatetimeIndex(['2023-01-01 00:00:00', '2023-02-10 10:40:00',
#                '2023-03-22 21:20:00', '2023-05-02 08:00:00',
#                '2023-06-11 18:40:00', '2023-07-22 05:20:00',
#                '2023-08-31 16:00:00', '2023-10-11 02:40:00',
#                '2023-11-20 13:20:00', '2023-12-31 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### Create a new column for the order delivery time (difference between 'Ship Date' and 'Order Date').

# %%
data['Delivery_time']=(data['Ship Date']-data['Order Date']).dt.days
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Total_Order_Value profit margin price_after_discount  \
# ...

# %% [markdown]
# ### Display current date

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2024-08-23 06:24:11.938645

# %% [markdown]
# ### Create a feature that calculates the age of an order in days from the order date to today’s date.

# %%
data['Order age']=(datetime.datetime.now()-data['Order Date']).dt.days
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... profit margin price_after_discount Shipping_cost_per_unit order_year  \
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority', 'Total_Order_Value',
#        'profit margin', 'price_after_discount', 'Shipping_cost_per_unit',
#        'order_year', 'order_month', 'order_month_name', 'order_day',
#        'order_day_name', 'Delivery_time', 'Order age'],
#       dtype='object')

# %% [markdown]
# ### Average Shipping Delay for Orders Placed in December

# %%
december_orders = data[data['Order Date'].dt.month == 12]
december_orders.head()
# Out:
#     Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 12   45794   SA-2012-MM7260110-41269 2012-12-26 2012-12-28    Second Class
# 19   49463   TZ-2015-RH9555129-42343 2015-12-05 2015-12-07    Second Class
# 26   30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 30     220   US-2012-RR1952536-41270 2012-12-27 2012-12-29    Second Class
# 32   40977  CA-2013-AH10030140-41635 2013-12-27 2013-12-31  Standard Class
#
#      Customer ID    Customer Name    Segment Postal Code           City  ...  \
# 12    MM-7260110  Magdelene Morse   Consumer         nan          Jizan  ...
# 19    RH-9555129  Ritsa Hightower   Consumer         nan         Uvinza  ...
# 26   PB-19210127   Phillip Breyer  Corporate         nan         Taipei  ...
# 30    RR-1952536        Rick Reed  Corporate         nan  Santo Domingo  ...
# 32  AH-100301404    Aaron Hawkins  Corporate     94122.0  San Francisco  ...
#
# ...

# %%
avg_delay = (december_orders['Ship Date'] - december_orders['Order Date']).mean()
print(avg_delay)
# Out:
# 3 days 22:53:29.333546428

# %% [markdown]
# # Replace

# %%
data['Ship Mode'].unique()
# Out:
# array(['First Class', 'Second Class', 'Same Day', 'Standard Class'],
#       dtype=object)

# %% [markdown]
# ### How can you replace all instances of the word "Standard Class" with "Std" in the 'Ship Mode' column

# %%
data['Ship Mode']=data['Ship Mode'].replace('Standard Class','Std')

# %%
data['Ship Mode'].unique()
# Out:
# array(['First Class', 'Second Class', 'Same Day', 'Std'], dtype=object)

# %%
data['Order Priority'].unique()
# Out:
# array(['High', 'Critical', 'Medium', 'Low'], dtype=object)

# %% [markdown]
# ### Replace 'Low' value in 'Order Priority' column with 'Standard' .

# %%
data['Order Priority']=data['Order Priority'].replace('Low','Standard')
data['Order Priority'].unique()
# Out:
# array(['High', 'Critical', 'Medium', 'Standard'], dtype=object)

# %% [markdown]
# # Filter& Sort

# %%
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... profit margin price_after_discount Shipping_cost_per_unit order_year  \
# ...

# %%
df= data[data['Segment']=='Consumer']
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date    Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13  First Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18  First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06     Same Day
# 6   30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08  First Class
# 7   31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18          Std
#
#     Customer ID  Customer Name   Segment Postal Code           City  ...  \
# 0  AB-100151402  Aaron Bergman  Consumer     73120.0  Oklahoma City  ...
# 2     CR-127307   Craig Reiter  Consumer         nan       Brisbane  ...
# 4    RH-9495111    Rick Hansen  Consumer         nan          Dakar  ...
# 6    TS-2134092  Toby Swindell  Consumer         nan        Porirua  ...
# 7    MB-1808592     Mick Brown  Consumer         nan       Hamilton  ...
#
#   profit margin price_after_discount Shipping_cost_per_unit order_year  \
# ...

# %%
data['Profit'].unique()
# Out:
# array([  62.1544, -288.765 ,  919.971 , ...,   22.0472,  -49.572 ,
#          -6.456 ])

# %% [markdown]
# ## Filter the rows where profit less than 0

# %%
pf_low=data[data['Profit']<0]
pf_low.head()
# Out:
#     Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 1    26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 3    13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 16   39519  CA-2012-AB10015140-40958 2012-02-19 2012-02-25           Std
# 30     220   US-2012-RR1952536-41270 2012-12-27 2012-12-29  Second Class
# 40   21316   ID-2014-JB1600059-41873 2014-08-22 2014-08-26           Std
#
#      Customer ID     Customer Name      Segment Postal Code           City  \
# 1      JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 3     KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 16  AB-100151402     Aaron Bergman     Consumer     76017.0      Arlington
# 30    RR-1952536         Rick Reed    Corporate         nan  Santo Domingo
# 40    JB-1600059         Joy Bell-     Consumer         nan        Mataram
#
# ...

# %% [markdown]
# ## Filter rows where the 'Profit' is negative and the 'Quantity' is greater than 10?

# %%
filter_rows=data[(data['Profit']<0) & (data['Quantity']>10)]
filter_rows.head()
# Out:
#      Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 109   11743   IT-2014-VM2168591-41711 2014-03-13 2014-03-13      Same Day
# 289   43395  TU-2013-SF10200134-41417 2013-05-23 2013-05-26   First Class
# 298   16456  IT-2013-JD16060120-41515 2013-08-29 2013-09-01   First Class
# 362   29513   ID-2014-SN2056097-41896 2014-09-14 2014-09-14      Same Day
# 368   29552   IN-2015-SV2078559-42110 2015-04-16 2015-04-18  Second Class
#
#      Customer ID     Customer Name      Segment Postal Code            City  \
# 109   VM-2168591   Valerie Mitchum  Home Office         nan  Bergen op Zoom
# 289  SF-10200134      Sarah Foster     Consumer         nan           Izmir
# 298  JD-16060120      Julia Dunbar     Consumer         nan       Santander
# 362   SN-2056097      Skye Norling  Home Office         nan          Lahore
# 368   SV-2078559  Stewart Visinsky     Consumer         nan           Medan
#
# ...

# %% [markdown]
# ## Calculate the average sales of these filtered rows

# %%
filter_rows['Sales'].mean()
# Out:
# 650.2714193333333

# %% [markdown]
# ## Modify the 'Order Priority' column to label all orders with a 'Profit' below zero as "Urgent"?

# %%
data.loc[data['Profit']<0, 'Order Priority']='Urgent'

# %%
data['Order Priority'].unique()
# Out:
# array(['High', 'Urgent', 'Medium', 'Critical', 'Standard'], dtype=object)

# %%
data.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... profit margin price_after_discount Shipping_cost_per_unit order_year  \
# ...

# %%
data['Order Priority']
# Out:
# 0            High
# 1          Urgent
# 2          Medium
# 3          Urgent
# 4        Critical
#            ...
# 51285      Medium
# 51286        High
# 51287        High
# 51288      Medium
# 51289        High
# Name: Order Priority, Length: 51290, dtype: object

# %% [markdown]
# # How  many rows have 'Urgent'as the Order Priority

# %%
len(data[data['Order Priority']=='Urgent'])
# Out:
# 12544

# %%
data[data['Order Priority']=='Urgent'].shape[0]
# Out:
# 12544

# %% [markdown]
# ## Filter data where category is 'Furniture' and profit is greater than 1000

# %%
data['Category'].unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %%
fur=data[(data['Category']=='Furniture')& (data['Profit']>1000)]
fur.head()
# Out:
#     Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 42   25795   IN-2015-VG2180558-42273 2015-09-26 2015-09-28  Second Class
# 66   16653  IT-2015-DK13090120-42345 2015-12-07 2015-12-08   First Class
# 70   21191   IN-2014-AS1022527-41797 2014-06-07 2014-06-09   First Class
# 72   49085    CG-2014-BW106533-41727 2014-03-29 2014-03-31  Second Class
# 88   27962   IN-2014-BK1126011-41940 2014-10-28 2014-10-31   First Class
#
#     Customer ID      Customer Name    Segment Postal Code                City  \
# 42   VG-2180558        Vivek Grady  Corporate         nan  Thiruvananthapuram
# 66  DK-13090120          Dave Kipp   Consumer         nan             Seville
# 70   AS-1022527  Alan Schoenberger  Corporate         nan               Jinan
# 72    BW-106533      Barry Weirich   Consumer         nan             Kananga
# 88   BK-1126011     Berenike Kampe   Consumer         nan               Tongi
#
# ...

# %% [markdown]
# ## Filter rows where product name contain word 'phone'

# %%
ph=data[data['Product Name'].str.contains('Phone')]
ph.head()
# Out:
#     Row ID                 Order ID Order Date  Ship Date     Ship Mode  \
# 2    25330   IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3    13524  ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 5    22732   IN-2014-JM156557-41818 2014-06-28 2014-07-01  Second Class
# 12   45794  SA-2012-MM7260110-41269 2012-12-26 2012-12-28  Second Class
# 24    1570  US-2015-NP1832582-42216 2015-07-31 2015-08-01   First Class
#
#    Customer ID     Customer Name      Segment Postal Code      City  ...  \
# 2    CR-127307      Craig Reiter     Consumer         nan  Brisbane  ...
# 3   KM-1637548  Katherine Murray  Home Office         nan    Berlin  ...
# 5    JM-156557       Jim Mitchum    Corporate         nan    Sydney  ...
# 12  MM-7260110   Magdelene Morse     Consumer         nan     Jizan  ...
# 24  NP-1832582      Naresj Patel     Consumer         nan    Juárez  ...
#
#    profit margin price_after_discount Shipping_cost_per_unit order_year  \
# ...

# %%
data['Product Name'].unique()
# Out:
# array(['Samsung Convoy 3', 'Novimex Executive Leather Armchair, Black',
#        'Nokia Smart Phone, with Caller ID', ...,
#        'Belkin 8 Outlet SurgeMaster II Gold Surge Protector with Phone Protection',
#        'Hewlett-Packard Deskjet D4360 Printer', 'Cisco SPA 501G IP Phone'],
#       dtype=object)

# %%
data['Product Name'].value_counts()
# Out:
# Product Name
# Staples                                                 227
# Cardinal Index Tab, Clear                                92
# Eldon File Cart, Single Width                            90
# Rogers File Cart, Single Width                           84
# Ibico Index Tab, Clear                                   83
#                                                        ...
# Lexmark X 9575 Professional All-in-One Color Printer      1
# NETGEAR RangeMax WNR1000 Wireless Router                  1
# 4009 Highlighters                                         1
# Xerox 1938                                                1
# Cisco SPA 501G IP Phone                                   1
# Name: count, Length: 3788, dtype: int64

# %% [markdown]
# ## Filter the dataset to include only rows where the 'Order Date' is between '2013-01-01' and '2014-12-31'?

# %%
data.describe(include='datetime')
# Out:
#                           Order Date                      Ship Date
# count                          51290                          51290
# mean   2014-05-11 21:26:49.155780608  2014-05-15 20:42:42.745174528
# min              2012-01-01 00:00:00            2012-01-03 00:00:00
# 25%              2013-06-19 00:00:00            2013-06-23 00:00:00
# 50%              2014-07-08 00:00:00            2014-07-12 00:00:00
# 75%              2015-05-22 00:00:00            2015-05-26 00:00:00
# max              2015-12-31 00:00:00            2016-01-07 00:00:00

# %%
data[(data['Order Date']>'2013-01-01') & (data['Order Date']<'2014-12-31')]
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
# ...       ...                       ...        ...        ...           ...
# 51280   35112  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09      Same Day
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31   First Class
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10           Std
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21           Std
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26  Second Class
#
# ...

# %% [markdown]
# # Sorting

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority', 'Total_Order_Value',
#        'profit margin', 'price_after_discount', 'Shipping_cost_per_unit',
#        'order_year', 'order_month', 'order_month_name', 'order_day',
#        'order_day_name', 'Delivery_time', 'Order age'],
#       dtype='object')

# %%
data['Sales'].sort_values(ascending=False)
# Out:
# 47114    22638.480
# 49003    17499.950
# 44248    13999.960
# 49940    11199.968
# 25238    10499.970
#            ...
# 24977        0.876
# 26588        0.852
# 33493        0.836
# 45391        0.556
# 51260        0.444
# Name: Sales, Length: 51290, dtype: float64

# %%
data[['Product Name','Sales']].sort_values(by='Sales',ascending=False)
# Out:
#                                             Product Name      Sales
# 47114  Cisco TelePresence System EX90 Videoconferenci...  22638.480
# 49003              Canon imageCLASS 2200 Advanced Copier  17499.950
# 44248              Canon imageCLASS 2200 Advanced Copier  13999.960
# 49940              Canon imageCLASS 2200 Advanced Copier  11199.968
# 25238              Canon imageCLASS 2200 Advanced Copier  10499.970
# ...                                                  ...        ...
# 24977                                  Acco 3-Hole Punch      0.876
# 26588                      Avery Round Ring Poly Binders      0.852
# 33493  Avery Durable Slant Ring Binders With Label Ho...      0.836
# 45391           Acco Suede Grain Vinyl Round Ring Binder      0.556
# 51260  Hoover Replacement Belt for Commercial Guardsm...      0.444
#
# [51290 rows x 2 columns]

# %% [markdown]
# ## Sort the dataset first by 'Category' in ascending order and then by 'Profit' in descending order?

# %%
data[['Category','Profit']].sort_values(by=['Category','Profit'],ascending=[True,False])
# Out:
#          Category     Profit
# 334     Furniture  2316.5100
# 42      Furniture  2097.0300
# 192     Furniture  2071.4400
# 118     Furniture  1868.1300
# 940     Furniture  1622.8800
# ...           ...        ...
# 362    Technology -3009.4350
# 47527  Technology -3399.9800
# 23110  Technology -3839.9904
# 6591   Technology -4088.3760
# 11755  Technology -6599.9780
#
# [51290 rows x 2 columns]

# %% [markdown]
# ## How can you sort the dataset by 'Quantity' in descending order and then select the top 10 records?

# %%
data.sort_values(by='Quantity',ascending=False).head(10)
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 7971    43213    CG-2015-JR570033-42272 2015-09-25 2015-09-30           Std
# 17405   19420  IT-2015-MG18205139-42242 2015-08-26 2015-08-29  Second Class
# 40522   34244  CA-2015-MP18175140-42353 2015-12-15 2015-12-19           Std
# 15388   26869    IN-2012-MW182357-41052 2012-05-23 2012-05-27           Std
# 33134   43138    NI-2014-PR888095-41982 2014-12-09 2014-12-11   First Class
# 13398   32726  US-2013-DK12835140-41578 2013-10-31 2013-11-04  Second Class
# 17675   47093     AU-2015-DA34508-42355 2015-12-17 2015-12-22           Std
# 10107   19306  ES-2013-SC20260139-41625 2013-12-17 2013-12-21  Second Class
# 2680    49660  TU-2013-TA11385134-41326 2013-02-21 2013-02-27           Std
# 31397   49851   PL-2015-BD1725103-42217 2015-08-01 2015-08-08           Std
#
#         Customer ID     Customer Name      Segment Postal Code           City  \
# ...

# %% [markdown]
# ## Sort the dataset by 'Order Date' in ascending order?

# %%
data.sort_values(by='Order Date',ascending=True)
# Out:
#        Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 22950   22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08           Std
# 43610   22254    IN-2012-JH159857-40909 2012-01-01 2012-01-08           Std
# 25078   48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05  Second Class
# 31870   22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08           Std
# 31583   11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05  Second Class
# ...       ...                       ...        ...        ...           ...
# 17379   10625   ES-2015-ES1402048-42369 2015-12-31 2016-01-04           Std
# 42870   32203  CA-2015-PO18865140-42369 2015-12-31 2016-01-04           Std
# 39873    5029   MX-2015-SC2026082-42369 2015-12-31 2016-01-02  Second Class
# 7908    28570  ID-2015-MY18295102-42369 2015-12-31 2016-01-04           Std
# 39602    7200   MX-2015-RB1946593-42369 2015-12-31 2015-12-31      Same Day
#
# ...
