# %% [markdown]
#  # <h1 style='background:#A3E4D8FF; border:0; color:black'><center>HEART FAILURE</center></h1>
#
# * Cardiovascular diseases are the most common cause of deaths globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worldwide.
# * Heart failure is a common event caused by Cardiovascular diseases.
# * It is characterized by the heart’s inability to pump an adequate supply of blood to the body.
# * Without sufficient blood flow, all major body functions are disrupted.
# * Heart failure is a condition or a collection of symptoms that weaken the heart.

# %% [markdown]
#  # **<span style="color:#AA6D7AFF;">TABLE OF CONTENTS</span>**
#
#
# **IMPORTING LIBRARIES**
#
# **LOADING DATA**
#
# **DATA ANALYSIS**
#
# **DATA PREPROCESSING**
#
# **MODEL BUILDING**
#
# **CONCLUSIONS**
#
# # **<span style="color:#AC5564FF;">IMPORTING LIBRARIES</span>**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import tensorflow 
from tensorflow import keras 
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential
from keras import callbacks
from sklearn.metrics import  classification_report

# %% [markdown]
# # **<span style="color:#AC6079FF;">LOADING DATA</span>**

# %%
#loading data
data = pd.read_csv("heart_failure_clinical_records_dataset.csv")
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# **About the data:**
#
# * age: Age of the patient
# * anaemia: If the patient had the haemoglobin below the normal range
# * creatinine_phosphokinase: The level of the creatine phosphokinase in the blood in mcg/L
# * diabetes: If the patient was diabetic
# * ejection_fraction: Ejection fraction is a measurement of how much blood the left ventricle pumps out with each contraction
# * high_blood_pressure: If the patient had hypertension
# * platelets: Platelet count of blood in kiloplatelets/mL
# * serum_creatinine: The level of serum creatinine in the blood in mg/dL
# * serum_sodium: The level of serum sodium in the blood in mEq/L
# * sex: The sex of the patient
# * smoking: If the patient smokes actively or ever did in past
# * time: It is the time of the patient's follow-up visit for the disease in months
# * DEATH_EVENT: If the patient deceased during the follow-up period

# %% [markdown]
# # **<span style="color:#6daa9f;">DATA ANALYSIS</span>**
#
# Steps in data analysis and visulisation:
#
# We begin our analysis by plotting a count plot of the targer attribute.
# A corelation matrix od the various attributes to examine the feature importance.

# %%
plt.figure(figsize=(5,4))
plt.title('Distribution of Death Event')
sns.countplot(x= data["DEATH_EVENT"])
plt.show()

# %% [markdown]
# Point to note is that there is an imbalance in the data.

# %%
corrmat = data.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,annot=True, square=True);

# %% [markdown]
# **Notable points:**
# * Time of the patient's follow-up visit for the disease is crucial in as initial diagnosis with cardiovascular issue and treatment reduces the chances of any fatality. It holds and inverse relation.
# * Ejection fraction is the second most important feature. It is quite expected as it is basically the efficiency of the heart.
# * Age of the patient is the third most correlated feature. Clearly as heart's functioning declines with ageing
#
# **Next, we will examine the count plot of age.**

# %%
data['age']=data['age'].astype('int64')

# %%
#Evauating age distrivution 
plt.figure(figsize=(20,12))
Days_of_week=sns.countplot(x=data['age'],data=data, hue ="DEATH_EVENT")
Days_of_week.set_title("Distribution Of Age", color="#774571");

# %%
# # Boxen and swarm plot of some non binary features.
# feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
# for i in feature:
#     plt.figure(figsize=(8,8))
#     sns.swarmplot(x=data["DEATH_EVENT"], y=data[i], color="black", alpha=0.5)
#     sns.boxenplot(x=data["DEATH_EVENT"], y=data[i])
#     plt.show()

# %%
# Boxen and swarm plot of some non binary features.
feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
for i in feature:
    plt.figure(figsize=(8,8))
    sns.swarmplot(x=data["DEATH_EVENT"], y=data[i], color="black", alpha=0.5)
    sns.boxplot(x=data["DEATH_EVENT"], y=data[i])
    plt.show()
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# I spotted outliers on our dataset. I didn't remove them yet as it may lead to overfitting. Though we may end up with better statistics. In this case, with medical data, the outliers may be an important deciding factor.
#
# Next, we examine the kdeplot of time and age as they both are significant features.

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.829431     11.894997     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# DEATH_EVENT               299.0       0.321070      0.467670      0.0
#
#                                25%       50%       75%       max
# age                           51.0      60.0      70.0      95.0
# anaemia                        0.0       0.0       1.0       1.0
# creatinine_phosphokinase     116.5     250.0     582.0    7861.0
# diabetes                       0.0       0.0       1.0       1.0
# ejection_fraction             30.0      38.0      45.0      80.0
# high_blood_pressure            0.0       0.0       1.0       1.0
# platelets                 212500.0  262000.0  303500.0  850000.0
# serum_creatinine               0.9       1.1       1.4       9.4
# serum_sodium                 134.0     137.0     140.0     148.0
# sex                            0.0       1.0       1.0       1.0
# smoking                        0.0       0.0       1.0       1.0
# time                          73.0     115.0     203.0     285.0
# DEATH_EVENT                    0.0       0.0       1.0       1.0

# %% [markdown]
# # **<span style="color:#6daa9f;">DATA PREPROCESSING</span>**
#
# **Steps involved in Data Preprocessing**
# * Dropping the outliers based on data analysis
# * Assigning values to features as X and target as y
# * Perform the scaling of the features
# * Split test and training sets

# %%
#assigning values to features as X and target as y
X=data.drop(["DEATH_EVENT"],axis=1)
y=data["DEATH_EVENT"]

# %%
X.head()
# Out:
#    age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0   75        0                       582         0                 20
# 1   55        0                      7861         0                 38
# 2   65        0                       146         0                 20
# 3   50        1                       111         0                 20
# 4   65        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time
# 0        0     4
# 1        0     6
# 2        1     7
# 3        0     7
# 4        0     8

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X, y)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import  train_test_split

# %%
#spliting test and training sets
X_train, X_test, y_train,y_test = train_test_split(X_res,y_res,test_size=0.2,random_state=42,shuffle = True)

# %%
scaler=StandardScaler()
X_train_sc=pd.DataFrame(scaler.fit_transform(X_train),columns=X_train.columns)
X_test_sc=pd.DataFrame(scaler.transform(X_test),columns=X_train.columns)

# %%
X_train_sc.head()
# Out:
#         age   anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  1.166633 -0.761898                 -0.526972 -0.731809           0.116137
# 1 -1.059976  1.312513                 -0.513676 -0.731809          -1.392346
# 2  0.721311  1.312513                 -0.499358 -0.731809          -0.973323
# 3 -0.169332  1.312513                  0.479371  1.366476           0.702769
# 4  0.275990  1.312513                 -0.511631  1.366476           1.959837
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium       sex  \
# 0            -0.668153  -0.391810          0.929476     -0.538588  0.872278
# 1            -0.668153  -0.534354          0.374297      0.156641  0.872278
# 2             1.496663  -0.260011         -0.489458      0.851871 -1.146423
# 3            -0.668153  -0.127920          4.405153     -1.233818  0.872278
# 4             1.496663  -0.605480         -0.585431      0.851871 -1.146423
#
#     smoking      time
# 0 -0.563093  0.553366
# 1 -0.563093 -1.450977
# 2 -0.563093 -1.346175
# 3 -0.563093 -0.140949
# 4 -0.563093 -0.311253

# %%
#looking at the scaled features
colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = X_train_sc,palette = colours)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13896\1025767989.py:4: UserWarning:
# The palette list has fewer values (5) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   sns.boxenplot(data = X_train_sc,palette = colours)

# %% [markdown]
# # **<span style="color:#6daa9f;">MODEL BUILDING</span>**
#
# In this project, we build an artificial neural network.
#
# **Following steps are involved in the model building**
# * Initialising the ANN
# * Defining by adding layers
# * Compiling the ANN
# * Train the ANN

# %%
# Initialising the NN
model = Sequential()
# layers
model.add(Dense(units = 32,  activation = 'relu', input_dim = 12))
model.add(Dense(units = 16, activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 8, activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 1, activation = 'sigmoid'))
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# from keras import layers


# model=keras.Sequential([
#     layers.Dense(units = 32,  activation = 'relu', input_dim = 12),
#     layers.Dense(units = 16, activation = 'relu'),
#     layers.Dropout(0.25),
#     layers.Dense(units = 8, activation = 'relu'),
#     layers.Dropout(0.5),
#     layers.Dense(units = 1, activation = 'sigmoid')

# ])

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# %%
# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Train the ANN
history = model.fit(X_train_sc, y_train, batch_size = 32, epochs = 600,callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5185 - loss: 0.7041 - val_accuracy: 0.6000 - val_loss: 0.6912
# Epoch 2/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5477 - loss: 0.6937 - val_accuracy: 0.6154 - val_loss: 0.6823
# Epoch 3/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5430 - loss: 0.6919 - val_accuracy: 0.6923 - val_loss: 0.6731
# Epoch 4/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5474 - loss: 0.6751 - val_accuracy: 0.6769 - val_loss: 0.6651
# Epoch 5/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5411 - loss: 0.6860 - val_accuracy: 0.6769 - val_loss: 0.6587
# Epoch 6/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6375 - loss: 0.6493 - val_accuracy: 0.6769 - val_loss: 0.6514
# Epoch 7/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5957 - loss: 0.6574 - val_accuracy: 0.7385 - val_loss: 0.6432
# Epoch 8/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6378 - loss: 0.6543 - val_accuracy: 0.7692 - val_loss: 0.6339
# Epoch 9/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6627 - loss: 0.6336 - val_accuracy: 0.8000 - val_loss: 0.6211
# Epoch 10/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6934 - loss: 0.6080 - val_accuracy: 0.7846 - val_loss: 0.6053
# Epoch 11/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7346 - loss: 0.5937 - val_accuracy: 0.7692 - val_loss: 0.5942
# Epoch 12/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7575 - loss: 0.5951 - val_accuracy: 0.7231 - val_loss: 0.5813
# Epoch 13/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7340 - loss: 0.5767 - val_accuracy: 0.7538 - val_loss: 0.5709
# Epoch 14/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7351 - loss: 0.5648 - val_accuracy: 0.7538 - val_loss: 0.5563
# Epoch 15/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7233 - loss: 0.5915 - val_accuracy: 0.7846 - val_loss: 0.5414
# Epoch 16/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7517 - loss: 0.5534 - val_accuracy: 0.7692 - val_loss: 0.5266
# Epoch 17/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7789 - loss: 0.5315 - val_accuracy: 0.7692 - val_loss: 0.5106
# Epoch 18/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8058 - loss: 0.5064 - val_accuracy: 0.8000 - val_loss: 0.4973
# Epoch 19/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7616 - loss: 0.5144 - val_accuracy: 0.8154 - val_loss: 0.4835
# Epoch 20/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7740 - loss: 0.5079 - val_accuracy: 0.8154 - val_loss: 0.4680
# Epoch 21/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8186 - loss: 0.4700 - val_accuracy: 0.8154 - val_loss: 0.4546
# Epoch 22/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8052 - loss: 0.4420 - val_accuracy: 0.8154 - val_loss: 0.4415
# Epoch 23/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8099 - loss: 0.4474 - val_accuracy: 0.8154 - val_loss: 0.4298
# Epoch 24/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8479 - loss: 0.4261 - val_accuracy: 0.8154 - val_loss: 0.4190
# Epoch 25/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8428 - loss: 0.4510 - val_accuracy: 0.8154 - val_loss: 0.4095
# Epoch 26/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8261 - loss: 0.4254 - val_accuracy: 0.8462 - val_loss: 0.4011
# Epoch 27/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8061 - loss: 0.4429 - val_accuracy: 0.8308 - val_loss: 0.3946
# Epoch 28/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7658 - loss: 0.4530 - val_accuracy: 0.8308 - val_loss: 0.3894
# Epoch 29/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8859 - loss: 0.3579 - val_accuracy: 0.8308 - val_loss: 0.3833
# Epoch 30/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8134 - loss: 0.4428 - val_accuracy: 0.8308 - val_loss: 0.3802
# Epoch 31/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8034 - loss: 0.4140 - val_accuracy: 0.8308 - val_loss: 0.3776
# Epoch 32/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8174 - loss: 0.3852 - val_accuracy: 0.8308 - val_loss: 0.3739
# Epoch 33/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8364 - loss: 0.3706 - val_accuracy: 0.8308 - val_loss: 0.3709
# Epoch 34/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8355 - loss: 0.3635 - val_accuracy: 0.8308 - val_loss: 0.3688
# Epoch 35/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8274 - loss: 0.4009 - val_accuracy: 0.8308 - val_loss: 0.3660
# Epoch 36/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8153 - loss: 0.4004 - val_accuracy: 0.8308 - val_loss: 0.3656
# Epoch 37/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8737 - loss: 0.3584 - val_accuracy: 0.8308 - val_loss: 0.3655
# Epoch 38/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8743 - loss: 0.3563 - val_accuracy: 0.8308 - val_loss: 0.3661
# Epoch 39/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8679 - loss: 0.3246 - val_accuracy: 0.8308 - val_loss: 0.3655
# Epoch 40/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8779 - loss: 0.3447 - val_accuracy: 0.8308 - val_loss: 0.3621
# Epoch 41/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8658 - loss: 0.3244 - val_accuracy: 0.8154 - val_loss: 0.3610
# Epoch 42/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8625 - loss: 0.3606 - val_accuracy: 0.8462 - val_loss: 0.3635
# Epoch 43/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8521 - loss: 0.3592 - val_accuracy: 0.8308 - val_loss: 0.3619
# Epoch 44/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8809 - loss: 0.2732 - val_accuracy: 0.8308 - val_loss: 0.3598
# Epoch 45/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8886 - loss: 0.2854 - val_accuracy: 0.8308 - val_loss: 0.3577
# Epoch 46/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8606 - loss: 0.3222 - val_accuracy: 0.8308 - val_loss: 0.3583
# Epoch 47/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8815 - loss: 0.3231 - val_accuracy: 0.8308 - val_loss: 0.3579
# Epoch 48/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8741 - loss: 0.3262 - val_accuracy: 0.8308 - val_loss: 0.3580
# Epoch 49/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8627 - loss: 0.3141 - val_accuracy: 0.8308 - val_loss: 0.3567
# Epoch 50/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8902 - loss: 0.2900 - val_accuracy: 0.8308 - val_loss: 0.3545
# Epoch 51/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8760 - loss: 0.3156 - val_accuracy: 0.8462 - val_loss: 0.3540
# Epoch 52/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9019 - loss: 0.2991 - val_accuracy: 0.8462 - val_loss: 0.3540
# Epoch 53/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8695 - loss: 0.3220 - val_accuracy: 0.8615 - val_loss: 0.3520
# Epoch 54/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9033 - loss: 0.2518 - val_accuracy: 0.8615 - val_loss: 0.3526
# Epoch 55/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8859 - loss: 0.3066 - val_accuracy: 0.8615 - val_loss: 0.3543
# Epoch 56/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8781 - loss: 0.3043 - val_accuracy: 0.8615 - val_loss: 0.3524
# Epoch 57/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9110 - loss: 0.2761 - val_accuracy: 0.8615 - val_loss: 0.3524
# Epoch 58/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8914 - loss: 0.2590 - val_accuracy: 0.8615 - val_loss: 0.3547
# Epoch 59/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8707 - loss: 0.3158 - val_accuracy: 0.8615 - val_loss: 0.3539
# Epoch 60/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8936 - loss: 0.2690 - val_accuracy: 0.8615 - val_loss: 0.3534
# Epoch 61/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8999 - loss: 0.2752 - val_accuracy: 0.8615 - val_loss: 0.3549
# Epoch 62/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9140 - loss: 0.2524 - val_accuracy: 0.8615 - val_loss: 0.3548
# Epoch 63/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8958 - loss: 0.2793 - val_accuracy: 0.8615 - val_loss: 0.3558
# Epoch 64/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9067 - loss: 0.2639 - val_accuracy: 0.8615 - val_loss: 0.3569
# Epoch 65/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9017 - loss: 0.2765 - val_accuracy: 0.8615 - val_loss: 0.3519
# Epoch 66/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8833 - loss: 0.3001 - val_accuracy: 0.8615 - val_loss: 0.3512
# Epoch 67/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9016 - loss: 0.2501 - val_accuracy: 0.8615 - val_loss: 0.3497
# Epoch 68/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9380 - loss: 0.2350 - val_accuracy: 0.8615 - val_loss: 0.3523
# Epoch 69/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8717 - loss: 0.3288 - val_accuracy: 0.8615 - val_loss: 0.3578
# Epoch 70/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8857 - loss: 0.2686 - val_accuracy: 0.8615 - val_loss: 0.3620
# Epoch 71/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9271 - loss: 0.2064 - val_accuracy: 0.8615 - val_loss: 0.3665
# Epoch 72/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9190 - loss: 0.2582 - val_accuracy: 0.8615 - val_loss: 0.3624
# Epoch 73/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9109 - loss: 0.2591 - val_accuracy: 0.8615 - val_loss: 0.3607
# Epoch 74/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9120 - loss: 0.2451 - val_accuracy: 0.8615 - val_loss: 0.3606
# Epoch 75/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8734 - loss: 0.2767 - val_accuracy: 0.8615 - val_loss: 0.3625
# Epoch 76/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9136 - loss: 0.2549 - val_accuracy: 0.8615 - val_loss: 0.3647
# Epoch 77/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8853 - loss: 0.2772 - val_accuracy: 0.8615 - val_loss: 0.3630
# Epoch 78/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9149 - loss: 0.2460 - val_accuracy: 0.8615 - val_loss: 0.3631
# Epoch 79/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9164 - loss: 0.2466 - val_accuracy: 0.8615 - val_loss: 0.3625
# Epoch 80/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8894 - loss: 0.2423 - val_accuracy: 0.8615 - val_loss: 0.3656
# Epoch 81/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9180 - loss: 0.2005 - val_accuracy: 0.8615 - val_loss: 0.3665
# Epoch 82/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9056 - loss: 0.2531 - val_accuracy: 0.8615 - val_loss: 0.3698
# Epoch 83/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9231 - loss: 0.2592 - val_accuracy: 0.8615 - val_loss: 0.3714
# Epoch 84/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9494 - loss: 0.1958 - val_accuracy: 0.8615 - val_loss: 0.3726
# Epoch 85/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9463 - loss: 0.2175 - val_accuracy: 0.8615 - val_loss: 0.3714
# Epoch 86/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9038 - loss: 0.2086 - val_accuracy: 0.8615 - val_loss: 0.3718
# Epoch 87/600
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8930 - loss: 0.2601 - val_accuracy: 0.8615 - val_loss: 0.3744

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
print(f"val_ accuracy :",val_accuracy*100)
# Out:
# val_accuracy: 82.18%
# val_ accuracy : 82.17506737544619

# %% [markdown]
# **Plotting training and validation loss over epochs**

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %% [markdown]
# **Plotting training and validation accuracy over epochs**

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # **<span style="color:#6daa9f;">CONCLUSIONS</span>**
#
# **Concluding the model with:**
#
# * Testing on the test set
# * Evaluating the confusion matrix
# * Evaluating the classification report

# %%
# Predicting the test set results
y_pred = model.predict(X_test_sc)
# This converts y_pred into a Boolean array (or integer 0 and 1 array).
y_pred = (y_pred > 0.5)
np.set_printoptions()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.85        41
#            1       0.82      0.90      0.86        41
#
#     accuracy                           0.85        82
#    macro avg       0.86      0.85      0.85        82
# weighted avg       0.86      0.85      0.85        82
