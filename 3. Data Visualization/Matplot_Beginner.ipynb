# %% [markdown]
# # <div style="text-align: center; background-color:pink; font-family:Georgia, serif; color: black; padding: 20px;line-height: 1;border-radius:5px; border: 2px solid black;">Matplotlib</div>

# %% [markdown]
# ## Introduction
#
# Data visualization is the graphic representation of data. It involves producing images that communicate relationships among the represented data to viewers. Visualizing data is an essential part of data analysis and machine learning. We'll use Python libraries [Matplotlib](https://matplotlib.org) and [Seaborn](https://seaborn.pydata.org) to learn and apply some popular data visualization techniques. We'll use the words _chart_, _plot_, and _graph_ interchangeably here.

# %% [markdown]
# # Installation

# %%
# pip install matplotlib

# %% [markdown]
# # pyforest

# %%
# pip install pyforest

# %% [markdown]
# * Sometimes, it happens that we spent a huge amount of time importing some common libraries like NumPy, pandas, matplotlib, seaborn, nltk and many more. To remove this headache of importing such libraries manually, we have pyforest library.
#
# * It is that library which helps you to work directly without importing other libraries separately.
# * It itself adds up some of the highly usable libraries used in DataScience while we are using it

# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Line Chart
#
# The line chart is one of the simplest and most widely used data visualization techniques. A line chart displays information as a series of data points or markers connected by straight lines. You can customize the shape, size, color, and other aesthetic elements of the lines and markers for better visual clarity.
#
# Here's a Python list showing the yield of apples (tons per hectare) over six years

# %%
yield_apples = [0.85, 0.933, 0.962, 0.976, 0.981, 0.991]

# %% [markdown]
# We can visualize how the yield of apples changes over time using a line chart. To draw a line chart, we can use the `plt.plot` function.

# %%
plt.plot(yield_apples)

# %% [markdown]
# Calling the `plt.plot` function draws the line chart as expected. It also returns a list of plots drawn `[<matplotlib.lines.Line2D at 0x7ff70aa20760>]`, shown within the output. We can include a semicolon (`;`) at the end of the last statement in the cell to avoiding showing the output and display just the graph.

# %%
plt.plot(yield_apples);

# %% [markdown]
# ### Customizing the X-axis
#
# The X-axis of the plot currently shows list element indexes 0 to 5. The plot would be more informative if we could display the year for which we're plotting the data. We can do this by two arguments `plt.plot`.

# %%
years = [2000, 2001, 2002, 2003, 2004, 2005]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(years, yield_apples)

# %% [markdown]
# ### Axis Labels
#
# We can add labels to the axes to show what each axis represents using the `plt.xlabel` and `plt.ylabel` methods.

# %%
plt.plot(years,yield_apples)
plt.xlabel('year')
plt.ylabel('yield_apples')
plt.show()

# %% [markdown]
# # Adding title and marker

# %%
plt.title('Sales Distribution over year')
plt.plot(years,yield_apples,marker='*')

# %% [markdown]
# # Title

# %%
plt.plot(years,yield_apples)
plt.xlabel('year')
plt.ylabel('yield_apples')
plt.title('Yield from apples over years')
plt.show()

# %% [markdown]
# # Customizing Size

# %%
plt.figure(figsize=(8,5))
plt.plot(years,yield_apples)
plt.xlabel('year')
plt.ylabel('yield_apples')
plt.title('Yield from apples over years')
plt.show()

# %% [markdown]
# # Value Arrangements

# %%
plt.figure(figsize=(8,5))
plt.title('Sales Distribution over year')
plt.plot(years,yield_apples,marker='*')
plt.xlabel('year')
plt.ylabel('yield')
plt.xticks(rotation=90);

# %%
# Show

# %%
plt.figure(figsize=(8,5))
plt.title('Sales Distribution over year')
plt.plot(years,yield_apples,marker='*')
plt.xlabel('year')
plt.ylabel('yield')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Plotting Multiple Lines
#
# You can invoke the `plt.plot` function once for each line to plot multiple lines in the same graph. Let's compare the yields of apples vs. oranges .

# %%
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908 ]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]
years = [2010, 2011, 2012, 2013, 2014, 2015]

# %%
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908 ]

# %%
plt.plot(years,yield_apples)

# %%
plt.plot(years,oranges,color='g')

# %%
plt.figure(figsize=(8,6))
plt.plot(years,yield_apples,color='r',marker='D')
plt.plot(years,oranges,color='g',marker='s')
plt.xlabel('year')
plt.ylabel('yield')
plt.title('Sales distribution over year')
plt.show()

# %%
# Adding legends

# %%
plt.figure(figsize=(8,6))
plt.plot(years,yield_apples,color='green',marker='o')
plt.plot(years,oranges,color='orange',marker='*')
plt.xlabel('year')
plt.ylabel('yield')
plt.title('Sales distribution over year')
plt.legend(['Mango','Orange'])
plt.show()

# %% [markdown]
# # Bar Chart

# %% [markdown]
# * When comparing values between and/or among groups, bar plots are traditionally the visualization of choice.

# %% [markdown]
# ## Create a list of item types and save it as x using the following code:

# %%
x = ['Shirts', 'Pants','Shorts','Shoes']

# %% [markdown]
# ## Create a list of sales revenue and save it as y as follows:

# %%
x = ['Shirts', 'Pants','Shorts','Shoes']
y = [1000, 1200, 800, 1800]
y1=[800,1100,600,900]

# %%
plt.bar(x, y)
plt.show()

# %% [markdown]
# # Adding title

# %%
plt.title('Sales Revenue by Item Type')
plt.bar(x, y)
plt.show()

# %% [markdown]
# # Adding labels

# %%
plt.title('Sales Revenue by Item Type')
plt.bar(x, y)
plt.xlabel('Item Type')
plt.ylabel('Sales Revenue ($)')
plt.show()

# %% [markdown]
# * We are going to create a title that will change according to the data that is plotted

# %%
index_max_y=y.index(max(y))

# %% [markdown]
# * Save the item from list x with an index equaling that of index_of_max_y to the most_
# sold_item object

# %%
most_sold_item = x[index_max_y]

# %%
plt.title('{} Produce the Most Sales Revenue'.format(most_sold_item))
plt.bar(x, y)
plt.xlabel('Item Type')
plt.ylabel('Sales Revenue ($)')
plt.show()

# %% [markdown]
# * If we wish to convert the plot into a horizontal bar plot, we can do so by replacing .
#      # plt.bar(x, y) with plt.barh(x, y)

# %%
plt.title('Sales Revenue by Item Type')
plt.barh(x, y)
plt.xlabel('Sales Revenue ($)')
plt.ylabel('Item Type')
plt.grid(True)
plt.show()

# %% [markdown]
# # Stacked bar

# %% [markdown]
# * A stacked bar chart is a great way to visualize the composition of different categories within a group.

# %%
plt.title('Sales Revenue by Item Type')
plt.bar(x, y)
plt.bar(x,y1)
plt.xlabel('Item Type')
plt.ylabel('Sales Revenue ($)')
plt.legend(['c1','c2'])
plt.show()

# %%
import pandas as pd
data = {
    'Quarter': ['Q1', 'Q2', 'Q3', 'Q4'],
    'Product A': [10, 20, 30, 40],
    'Product B': [20, 25, 35, 45],
    'Product C': [30, 30, 40, 50]
}
df = pd.DataFrame(data)

# %%
# Set the 'Quarter' column as the index
df1=df.set_index('Quarter')

# %%
df1
# Out:
#          Product A  Product B  Product C
# Quarter
# Q1              10         20         30
# Q2              20         25         30
# Q3              30         35         40
# Q4              40         45         50

# %%
# Plot a stacked bar chart
df1.plot(kind='bar', stacked=True, figsize=(10, 6),colormap='magma')

plt.title('Sales by Product Across Quarters')
plt.xlabel('Quarters')
plt.ylabel('Sales')
plt.legend(title='Products')
plt.show()

# %%
df
# Out:
#   Quarter  Product A  Product B  Product C
# 0      Q1         10         20         30
# 1      Q2         20         25         30
# 2      Q3         30         35         40
# 3      Q4         40         45         50

# %%
# Plot each product's sales data
bottoms = np.zeros(len('Quarter'))  # Initialize bottoms for stacking
bottoms
# Out:
# array([0., 0., 0., 0., 0., 0., 0.])

# %%
# # Create a stacked bar chart
# plt.figure(figsize=(10, 6))

# # Plot each product's sales data
# bottoms = np.zeros(len('Quarter')) 

# for i, product in enumerate(products):
#     plt.bar(quarters, df[i], bottom=bottoms, label=product)
#     bottoms += df[i] 

# plt.xlabel('Quarters')
# plt.ylabel('Sales')
# plt.title('Sales by Product Across Quarters')
# plt.legend(title='Products')
# plt.show()

# %% [markdown]
# * Representing the number of units sold for different types of vehicles across three regions.

# %%
data = {
    'Region': ['North', 'South', 'East', 'West'],
    'Sedans': [150, 200, 180, 220],
    'SUVs': [120, 180, 160, 200],
    'Trucks': [80, 100, 90, 120]
}

df = pd.DataFrame(data)

# %%
# Set the 'Region' column as the index
df.set_index('Region', inplace=True)

# %%
# Plot a stacked bar chart
df.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='copper')

plt.title('Units Sold by Vehicle Type Across Regions')
plt.xlabel('Region')
plt.ylabel('Number of Units Sold')
plt.legend(title='Vehicle Type')
plt.show()

# %% [markdown]
# * Line plots and bar plots are two very common and effective types of visualizations for reporting trends and comparing groups, respectively. However, for deeper statistical analyses, it is important to generate graphs that uncover characteristics of features not apparent with line plots and bar plots

# %% [markdown]
# # Histogram

# %% [markdown]
# * In statistics, it is essential to be aware of the distribution of continuous variables prior to running any type of analysis. To display the distribution, we will use a histogram. Histograms display the frequency by the bin for a given array

# %% [markdown]
# ? Generate an array of 100 normally distributed values with a mean of 0 and a standard deviation of 0.1

# %%
import numpy as np
y = np.random.normal(loc=0, scale=0.1, size=100)
y
# Out:
# array([-0.06463907, -0.00734493, -0.15182605,  0.17878848, -0.06141738,
#         0.15338191,  0.02686917,  0.06012459, -0.05854449, -0.02029132,
#         0.09007992, -0.1237067 , -0.10268416,  0.05394313,  0.00667519,
#        -0.06399273,  0.09291683, -0.09771744,  0.0663156 ,  0.04806655,
#         0.14836019,  0.14101421, -0.07237727, -0.07880439, -0.11792223,
#         0.00049055,  0.10844172, -0.12095811,  0.05691066,  0.0626289 ,
#         0.0949851 ,  0.08001931, -0.01092621,  0.03476002,  0.04656399,
#        -0.12695499,  0.18787214, -0.03428266, -0.12830405, -0.15904938,
#         0.22744932, -0.08475723,  0.05621481,  0.0549401 ,  0.04257784,
#         0.06897459,  0.0674573 ,  0.08045079, -0.0093045 , -0.04831026,
#         0.02099187, -0.16691668, -0.01582185,  0.0618227 , -0.10685228,
#        -0.11063468,  0.03827506, -0.03343834,  0.05681977, -0.28046251,
#         0.13863995,  0.0944192 ,  0.13458503,  0.10361052, -0.10550022,
# ...

# %%
plt.hist(y, bins=20)
plt.xlabel('y Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ? Generates random humidity data between 20 and 100 for 100 observations.

# %%
# Sample data creation
np.random.seed(0)
# Random humidity 
humidity_data = np.random.randint(20, 100, size=100)

# %%
plt.figure(figsize=(8, 6))
plt.hist(humidity_data, bins=10, color='green', edgecolor='black')
plt.grid(True)
plt.show()

# %% [markdown]
# # Add title and labels

# %%
plt.figure(figsize=(8, 6))
plt.title('Distribution of Humidity Levels')
plt.hist(humidity_data, bins=10, color='red', edgecolor='black')
plt.xlabel('Humidity')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# * When we look at a histogram, we often determine whether the distribution is normal. Sometimes, a distribution may appear normal when it is not, and sometimes a distribution may appear not normal when it is normal.

# %% [markdown]
# # Box-and-whisker

# %% [markdown]
# * Another common statistical plot for exploring a numerical feature is a box-and-whisker plot, also referred to as a boxplot.

# %% [markdown]
# * Box-and-whisker plots display the distribution of an array based on the minimum, first quartile, median, third quartile, and maximum, but they are primarily used to indicate the skew of a distribution and to identify outliers.

# %% [markdown]
# ? Generate an array of 100 normally distributed numbers with a mean of 0 and a standard deviation of 0.1.

# %%
import numpy as np
y = np.random.normal(loc=0, scale=0.1, size=100)

# %%
plt.boxplot(y) 
plt.show()

# %% [markdown]
# * The plot displays a box that represents the interquartile range (IQR).
# * The bottom/left of the box is the 25th percentile (i.e., Q1) while the top/right of the box is the 75th percentile (that is, Q3).
# * The orange line going through the box is the median.
# * The two lines extending above and below the box are the whiskers.
# * The top of the upper whisker is the "maximum" value, which is calculated using Q1 – 1.5*IQR.
# * The bottom of the lower whisker is the "minimum" value, which is calculated using Q3 + 1.5*IQR.
# * Outliers (or fringe outliers) are displayed as dots above the "maximum" whisker or below the "minimum" whisker.

# %%
# Sample data creation
import pandas as pd
data = {
   
    'windspeed': [10, 15, 8, 20, 12, 0, 7, 14, 21, 18, 9, 6, 3, 11, 5, 13, 17, 19, 22, 16, 8, 10, 7, 5, 13]
}
df = pd.DataFrame(data)

# %%
# Create box plot
plt.figure(figsize=(8, 6))
plt.boxplot(df['windspeed'], patch_artist=True)

# Add title and labels
plt.title('Box Plot of Wind Speed')
plt.xlabel('Wind Speed')
plt.ylabel('Value')

# Show plot
plt.show()

# %% [markdown]
# # violin plot

# %% [markdown]
# * A violin plot is similar to a box plot but provides additional information about the density distribution of the data.
# * It combines aspects of a box plot and a kernel density plot, showing the distribution shape, central tendency, and variability

# %%
# Create box plot
plt.figure(figsize=(8, 6))
plt.violinplot(df['windspeed'])

# Add title and labels
plt.title('Violin Plot of Wind Speed')
plt.xlabel('Wind Speed')
plt.ylabel('Value')

# Show plot
plt.show()

# %% [markdown]
# # Scatterplot

# %% [markdown]
# * Histograms and box-and-whisker plots are effective in exploring the characteristics of numerical arrays.
# * However, they do not provide information on the relationships between arrays.
# * A scatter plot is a type of data visualization used to display the relationship between two numerical variables.
# * Each point on the plot represents an observation, with its position determined by the values of the two variables.
# * Scatter plots are useful for identifying trends, correlations, and patterns in data.

# %% [markdown]
# ? Generate a list of numbers representing height and save it as y and weight save it as x

# %%
y = [5, 5.5, 5, 5.5, 6, 6.5, 6, 6.5, 7, 5.5, 5.25, 6, 5.25]

# %%
x = [100, 150, 110, 140, 140, 170, 168, 165, 180, 125, 115, 155, 135]

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y);

# %% [markdown]
# # Adding title,label,grid

# %%
plt.figure(figsize=(6,5))
plt.title("Weight vs Height")
plt.xlabel('Weight')
plt.ylabel("Height")
plt.scatter(x, y);

# %% [markdown]
# * We want our plot title to inform the reader about the strength of the relationship and the Pearson correlation coefficient. Thus, we will calculate the Pearson correlation coefficient and interpret the value of the coefficient in the title. To compute the Pearson correlation coefficient

# %% [markdown]
# # Pearson Correlation Coefficient (r):
#
# * The Pearson correlation coefficient is a measure of the linear relationship between two variables. It ranges from -1 to 1:
#
#     * 1: Perfect positive linear relationship.
#     * 0: No linear relationship.
#     * -1: Perfect negative linear relationship.
#
#
# ### Returns
#
# * correlation_coefficient: The Pearson correlation coefficient (r value).
# * p_value: The two-tailed p-value for testing non-correlation.
#
#
# ### Interpretation
# * If r is close to 1 or -1 and the p-value is low (e.g., < 0.05), there is a strong linear relationship between x and y.
# * If r is close to 0 and the p-value is high, it indicates little to no linear relationship between x and y.

# %%
from scipy.stats import pearsonr
correlation_coeff, p_value = pearsonr(x, y)

# %%
correlation_coeff
# Out:
# 0.906224645847121

# %%
p_value
# Out:
# 1.9704521537621127e-05

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a sample DataFrame
np.random.seed(42)
data = {
    'Feature X': np.random.normal(loc=50, scale=10, size=100),  # Normal distribution
    'Feature Y': np.random.normal(loc=60, scale=15, size=100)   # Normal distribution
}

df = pd.DataFrame(data)

# %% [markdown]
#  * A higher standard deviation means that the values will be more spread out from the mean, resulting in a wider and flatter distribution.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Feature X'], df['Feature Y'], alpha=0.8, edgecolor='black')

plt.title('Scatter Plot of Feature X vs. Feature Y')
plt.xlabel('Feature X')
plt.ylabel('Feature Y')
plt.grid(True)

plt.show()

# %%
import seaborn as sns

# Create a scatter plot with a trend line
plt.figure(figsize=(10, 6))
sns.regplot(x='Feature X', y='Feature Y', data=df, scatter_kws={'alpha':0.7, 'edgecolor':'black'}, line_kws={'color':'red'})

plt.title('Scatter Plot with Trend Line')
plt.xlabel('Feature X')
plt.ylabel('Feature Y')
plt.grid(True)

plt.show()

# %% [markdown]
# * sns.regplot() generates the scatter plot with a linear regression trend line.
# * scatter_kws specifies keyword arguments for the scatter plot (e.g., transparency and edge color).
# * line_kws specifies keyword arguments for the trend line (e.g., color).

# %% [markdown]
# # Pie Chart

# %% [markdown]
# * In a pie chart, each slice stands for a different category, and the size of the slice shows how much of the total each category makes up.
#
# * Consider a company's budget where the spending is divided among different departments
#      * Marketing
#      * Research & Development
#      * Sales, and Operations
# * A pie chart could effectively show how much of the total budget each department consumes, allowing stakeholders to visually grasp the relative importance or scale of spending in each area.

# %%
# Data to plot
labels = ['Category A', 'Category B', 'Category C', 'Category D']
# The sizes for each slice
sizes = [20, 30, 25, 25] 
# Optional: custom colors
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue'] 
# Explode the 1st slice 
explode = (0.1, 0, 0, 0)

# %%
plt.pie(sizes, explode=(0,0,0.1,0), labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=10);
plt.title('Company Budget Distribution Across Departments');

# %% [markdown]
# # Explanation:
# * labels: A list of labels for each slice of the pie.
# * sizes: A list of numerical values that determine the size of each slice. The total of these values is used to determine the proportional size of each slice.
# * colors: (Optional) A list of colors for each slice.
# * explode: (Optional) A tuple that indicates how much to "explode" or separate each slice from the pie. For example, (0.1, 0, 0, 0) will pull the first slice out by 0.1 units.
# * autopct: (Optional) A string format to label the slices with their percentage value (e.g., '%1.1f%%').
# * shadow: (Optional) Adds a shadow to the pie chart.
# * startangle: (Optional) Rotates the chart to start from a different angle (e.g., 140 degrees).

# %% [markdown]
# ### Another way

# %%
# sample data
data = {
      'season': [1, 1, 2, 2],
    'count': [16, 40, 32, 13]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    season  count
# 0       1     16
# 1       1     40
# 2       2     32
# 3       2     13

# %%
season_counts=df.groupby('season')['count'].mean()

# %%
season_counts.plot(kind='pie',colors=['green','gold'],explode=(0,0.1),shadow=True,autopct="%1.1f%%");

# %% [markdown]
# # Object-Oriented Approach Using Subplots

# %% [markdown]
# * In the object-oriented approach, we create a figure object that acts as an empty canvas and then we add a set of axes, or subplots, to it
# * Another advantage of using the object-oriented plotting approach is the ability to create multiple subplots on a single figure object.
# * In some situations, we want to compare different views of data side by side. We can accomplish this in Matplotlib using subplots

# %% [markdown]
# ? First, create x, y, and y2 using the following code:

# %%
import numpy as np
x = np.linspace(0, 10, 20)
y = x**3
y2 = x**2

# %%
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %% [markdown]
# ? Create a figure with two axes (that is, subplots) that are side by side (that is, 1 row
# with 2 columns)

# %% [markdown]
# * The fig object is now callable and returns the axis on which we can plot

# %%
x

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x, y)
axes[0].set_title('x by x Cubed')
axes[0].set_xlabel('Linearly Spaced Numbers')
axes[0].set_ylabel('y Value')

axes[1].plot(x, y2)
axes[1].set_title('x by x Squared')
axes[1].set_xlabel('Linearly Spaced Numbers')
axes[1].set_ylabel('y Value')
plt.show()

# %% [markdown]
# * It looks like the y-axis of the plot on the right is overlapping the left-hand plot. To prevent the overlapping of the plots, use plt.tight_layout().

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x, y)
axes[0].set_title('x by x Cubed')
axes[0].set_xlabel('Linearly Spaced Numbers')
axes[0].set_ylabel('y Value')
axes[1].plot(x, y2)
axes[1].set_title('x by x Squared')
axes[1].set_xlabel('Linearly Spaced Numbers')
axes[1].set_ylabel('y Value')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data
np.random.seed(42)
x = np.random.normal(0, 1, 100)
y = np.random.normal(0, 1, 100)

# Create scatter plot with different alpha values
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(x, y, alpha=0.3, edgecolor='black')
plt.title('Alpha = 0.3')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.subplot(1, 2, 2)
plt.scatter(x, y, alpha=0.8, edgecolor='black')
plt.title('Alpha = 0.8')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Plots that primarily use numerical values include:
#
# * Histogram: Represents the distribution of numerical data by showing the frequency of data points within specified ranges (bins).
#
# * Box Plot (Box-and-Whisker Plot): Summarizes the distribution of numerical data through their quartiles and outliers.
#
# * Scatter Plot: Displays points based on two numerical variables, allowing you to see correlations or patterns.
#
# * Line Plot: Shows trends over time or continuous data by connecting data points with lines.
#
# * Bar Plot (with numerical data): Can be used when both the categories (on the x-axis) and their corresponding values (on the y-axis) are numerical.
#
# * Heatmap: Represents numerical data in a matrix format with colors indicating the magnitude of values.
#
# * Violin Plot: Combines a box plot with a density plot, showing the distribution of numerical data across different categories.
#
# * Density Plot: Estimates the probability density function of a continuous numerical variable.
#
# * Pair Plot: Displays scatter plots of all possible pairs of numerical variables in a dataset.

# %% [markdown]
# # Common plots that can use both categorical and numerical values:
#
# * Bar Plot: Visualizes the relationship between a categorical variable (x-axis) and a numerical variable (y-axis). Each bar represents a category.
#
# * Stacked Bar Plot: Similar to a bar plot but shows multiple categories within each bar, stacked on top of each other, allowing for comparison between different groups.
#
# * Pie Chart: Displays the proportions of different categories within a dataset. Each slice of the pie represents a category.
#
# * Box Plot (Box-and-Whisker Plot): While it primarily deals with numerical data, it can group the data by a categorical variable to compare distributions across categories.
#
# * Violin Plot: Combines a box plot and a density plot, displaying the distribution of numerical data across different categories.
#
# * Swarm Plot: Similar to a strip plot but adjusts points to avoid overlap, showing the distribution of a numerical variable across categories.
#
# * Count Plot: A type of bar plot that counts the occurrences of each category and displays them as bars.
#
# * Point Plot: Similar to a line plot but specifically used for categorical data, it shows the mean value of a numerical variable for each category, with points connected by lines.
#
# * Heatmap: Although primarily used for numerical data, it can also be applied when one or both axes represent categorical variables, showing how numerical values change across categories.

# %% [markdown]
# # Summary
# * In this chapter, we used the Python plotting library Matplotlib to create, customize plots using the functional approach.
# * We then covered the importance of a descriptive title and created our own descriptive, programmatic titles.
# * However, the functional approach does not create a callable figure object and it does not return subplots.
# * Thus, to create a callable figure object with the potential of numerous subplots, we created, customized, and saved our plots using the object-oriented approach.
