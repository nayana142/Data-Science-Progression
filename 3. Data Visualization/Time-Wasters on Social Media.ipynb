# %% [markdown]
# # <div style="text-align: center; background-color:pink; font-family:Georgia, serif; color: black; padding: 20px;line-height: 1;border-radius:5px; border: 2px solid black;">Social Media Menace Prediction</div>

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Loading

# %%
data=pd.read_csv('Time-Wasters on Social Media.csv')

# %% [markdown]
# ## Columns Description
# * UserID: Unique identifier assigned to each user.
# * Age: The user's age. - Gender: The user's gender (e.g., male, female, non-binary).
# * Location: Geographic location of the user.
# * Income: The user's income level.
# * Debt: Amount of debt the user has.
# * Owns Property: Indicates whether the user owns property.
# * Profession: The user's occupation or job.
# * Demographics: Statistical data about the user (e.g., age, gender, income).
# * Platform: The platform the user is using (e.g., website, mobile app).
# * Total Time Spent: The total time the user spends on the platform.
# * Number of Sessions: The number of times the user has logged into the platform.
# * Video ID: Unique identifier for a video.
# * Video Category: The category or genre of the video.
# * Video Length: Duration of the video.
# * Engagement: User interaction with the video (e.g., likes, comments, shares).
# * Importance Score: A score indicating how important the video is to the user.
# * Time Spent On Video: The amount of time the user spends watching a video.
# * Number of Videos Watched: The total number of videos watched by the user.
# * Scroll Rate: The rate at which the user scrolls through content.
# * Frequency: How often the user engages with the platform.
# * Productivity Loss: The impact of platform usage on the user's productivity.
# * Satisfaction: The user's satisfaction level with the platform or content.
# * Watch Reason: The reason why the user is watching a video (e.g., entertainment, education).
# * Device Type: The type of device the user is using (e.g., smartphone, tablet, desktop).
# * OS: The operating system of the user's device (e.g., iOS, Android, Windows).
# * Watch Time: The time of day when the user watches videos.
# * Self Control: The user's ability to control their usage of the platform.
# * Addiction Level: The user's level of dependency on the platform.
# * Current Activity: What the user is doing while watching the video.
# * Connection Type: The type of internet connection the user has (e.g., Wi-Fi, cellular).

# %% [markdown]
# # Data Exploratory Analysis

# %%
data
# Out:
#      UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0         1   56    Male       Pakistan   82812   True           True
# 1         2   46  Female         Mexico   27999  False           True
# 2         3   32  Female  United States   42436  False           True
# 3         4   60    Male         Barzil   62963   True          False
# 4         5   25    Male       Pakistan   22096  False           True
# ..      ...  ...     ...            ...     ...    ...            ...
# 995     996   22    Male          India   74254   True           True
# 996     997   40  Female       Pakistan   27006  False          False
# 997     998   27    Male          India   94218   True           True
# 998     999   61    Male       Pakistan   85344   True          False
# 999    1000   19    Male          India   53840   True           True
#
#         Profession Demographics   Platform  ...  ProductivityLoss  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   UserID                    1000 non-null   int64
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   object
#  3   Location                  1000 non-null   object
#  4   Income                    1000 non-null   int64
#  5   Debt                      1000 non-null   bool
#  6   Owns Property             1000 non-null   bool
#  7   Profession                1000 non-null   object
#  8   Demographics              1000 non-null   object
#  9   Platform                  1000 non-null   object
#  10  Total Time Spent          1000 non-null   int64
#  11  Number of Sessions        1000 non-null   int64
#  12  Video ID                  1000 non-null   int64
#  13  Video Category            1000 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# UserID                      0
# Age                         0
# Gender                      0
# Location                    0
# Income                      0
# Debt                        0
# Owns Property               0
# Profession                  0
# Demographics                0
# Platform                    0
# Total Time Spent            0
# Number of Sessions          0
# Video ID                    0
# Video Category              0
# Video Length                0
# Engagement                  0
# Importance Score            0
# Time Spent On Video         0
# Number of Videos Watched    0
# Scroll Rate                 0
# Frequency                   0
# ProductivityLoss            0
# Satisfaction                0
# Watch Reason                0
# DeviceType                  0
# OS                          0
# Watch Time                  0
# Self Control                0
# Addiction Level             0
# CurrentActivity             0
# ConnectionType              0
# ...

# %% [markdown]
# * No null values: cleaned data

# %% [markdown]
# # Description of numerical features

# %%
data.describe().T
# Out:
#                            count       mean           std      min       25%  \
# UserID                    1000.0    500.500    288.819436      1.0    250.75
# Age                       1000.0     40.986     13.497852     18.0     29.00
# Income                    1000.0  59524.213  23736.212925  20138.0  38675.25
# Total Time Spent          1000.0    151.406     83.952637     10.0     78.00
# Number of Sessions        1000.0     10.013      5.380314      1.0      6.00
# Video ID                  1000.0   4891.738   2853.144258     11.0   2542.00
# Video Length              1000.0     15.214      8.224953      1.0      8.00
# Engagement                1000.0   4997.159   2910.053701     15.0   2415.75
# Importance Score          1000.0      5.129      2.582834      1.0      3.00
# Time Spent On Video       1000.0     14.973      8.200092      1.0      8.00
# Number of Videos Watched  1000.0     25.248     14.029159      1.0     14.00
# ...

# %% [markdown]
# # Description of categorical features

# %%
data.describe(include='object').T
# Out:
#                 count unique          top freq
# Gender           1000      3         Male  514
# Location         1000     10        India  228
# Profession       1000      9     Students  246
# Demographics     1000      2        Rural  746
# Platform         1000      4       TikTok  273
# Video Category   1000      9  Jokes/Memes  179
# Frequency        1000      4      Evening  365
# Watch Reason     1000      4        Habit  339
# DeviceType       1000      3   Smartphone  585
# OS               1000      4      Android  500
# Watch Time       1000     16      2:00 PM  149
# CurrentActivity  1000      4      At home  381
# ConnectionType   1000      2  Mobile Data  686

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * No duplicate values

# %%
data.nunique()
# Out:
# UserID                      1000
# Age                           47
# Gender                         3
# Location                      10
# Income                       996
# Debt                           2
# Owns Property                  2
# Profession                     9
# Demographics                   2
# Platform                       4
# Total Time Spent             278
# Number of Sessions            19
# Video ID                     947
# Video Category                 9
# Video Length                  29
# Engagement                   953
# Importance Score               9
# Time Spent On Video           29
# Number of Videos Watched      49
# Scroll Rate                   99
# Frequency                      4
# ProductivityLoss               9
# Satisfaction                   9
# Watch Reason                   4
# DeviceType                     3
# OS                             4
# Watch Time                    16
# Self Control                   8
# ...

# %% [markdown]
# # Average Total Time Spent by Age Group

# %%
data.groupby('Age')['Total Time Spent'].mean().sort_values(ascending=False)
# Out:
# Age
# 37    183.500000
# 26    179.888889
# 62    179.080000
# 46    175.894737
# 21    173.052632
# 45    171.600000
# 35    170.812500
# 24    170.285714
# 23    169.956522
# 58    169.500000
# 27    164.666667
# 25    162.043478
# 54    161.296296
# 59    160.058824
# 20    159.583333
# 60    159.000000
# 39    156.727273
# 51    156.722222
# 53    156.260870
# 61    154.913043
# 64    154.666667
# 30    154.555556
# 55    154.437500
# 42    154.000000
# 47    151.809524
# 19    151.166667
# 22    146.480000
# 18    145.600000
# 38    145.210526
# 41    145.000000
# 57    145.000000
# 48    144.187500
# 43    144.000000
# 40    143.166667
# 52    141.321429
# 29    140.454545
# 28    139.200000
# 50    138.366667
# 49    138.120000
# 44    137.187500
# 34    135.681818
# 33    133.476190
# 63    131.615385
# 31    129.000000
# 36    119.600000
# 56    119.000000
# 32    114.888889
# Name: Total Time Spent, dtype: float64

# %% [markdown]
# # Top 10 Users by Total Time Spent on the Platform

# %%
user_spend=data[['UserID','Total Time Spent']].sort_values(by='Total Time Spent',ascending=False).reset_index(drop=True).head(10)
user_spend
# Out:
#    UserID  Total Time Spent
# 0     639               298
# 1     847               298
# 2     861               298
# 3     241               298
# 4     562               298
# 5      76               297
# 6     459               297
# 7     890               297
# 8     923               297
# 9     934               296

# %% [markdown]
# # Average Total Time Spent on Platform by User

# %%
data.groupby(['Platform'])['Total Time Spent'].mean().sort_values(ascending=False)
# Out:
# Platform
# Facebook     155.180995
# YouTube      152.820000
# TikTok       151.271062
# Instagram    146.910156
# Name: Total Time Spent, dtype: float64

# %%
data.groupby(['Platform'])['Total Time Spent'].mean().sort_values(ascending=False).plot(kind='bar',color= ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728'])
plt.title('Average Total Time Spent on Platform by User')
plt.ylabel('Average Time Spend');

# %% [markdown]
# # Distribution of Addiction Levels Among Users

# %%
data['Addiction Level'].value_counts()
# Out:
# Addiction Level
# 2    248
# 5    228
# 0    180
# 3    159
# 1     60
# 7     55
# 4     36
# 6     34
# Name: count, dtype: int64

# %%
data['Addiction Level'].value_counts().plot(kind='pie',explode=(0,0,0,0,0,0,0,0.1),shadow=True,autopct="%1.2f%%",title='Distribution of Addiction Levels Among Users');

# %% [markdown]
# # How many users have an addiction level greater than 5?

# %%
data[data['Addiction Level']>5]['UserID'].count()
# Out:
# 89

# %% [markdown]
# * Number of users with addiction level greater than 5: 89

# %% [markdown]
# # What is the distribution of video watch time across different times of day?

# %%
watch_time_distribution=data['Watch Time'].value_counts()
watch_time_distribution.plot(kind='bar',color='green',title='Distribution of video watch time across different times of day',ylabel='counts');

# %% [markdown]
# # Maximum Total Time Spent per Video Category

# %%
data.groupby(['Video Category'])['Total Time Spent'].max()
# Out:
# Video Category
# ASMR             295
# Comedy           297
# Entertainment    298
# Gaming           298
# Jokes/Memes      297
# Life Hacks       298
# Pranks           294
# Trends           295
# Vlogs            297
# Name: Total Time Spent, dtype: int64

# %%
data.groupby(['Video Category'])['Total Time Spent'].max().sort_values(ascending=True).plot(kind='barh',color='Orange')
plt.title('Maximum Total Time Spent per Video Category');

# %% [markdown]
# # What is the average number of videos watched per user?

# %%
data['Number of Videos Watched'].mean()
# Out:
# 25.248

# %% [markdown]
# # Which video has the highest importance score?

# %%
data[['Video ID','Video Category','Importance Score']].loc[data['Importance Score'].idxmax()]
# Out:
# Video ID             3230
# Video Category      Vlogs
# Importance Score        9
# Name: 6, dtype: object

# %% [markdown]
# # What is the scroll rate distribution based on platform

# %%
sc_rate=data.groupby(['Platform'])['Scroll Rate'].mean()
sc_rate
# Out:
# Platform
# Facebook     46.769231
# Instagram    52.230469
# TikTok       50.293040
# YouTube      49.348000
# Name: Scroll Rate, dtype: float64

# %%
sc_rate.plot(kind='pie',explode=(0,0,0,0.1),shadow=True,autopct="%1.2f%%",title='Scroll Rate Distribution Based On Platform');

# %% [markdown]
# # Average Satisfaction by Gender and Video Category

# %%
data.groupby(['Gender','Video Category'])['Satisfaction'].mean()
# Out:
# Gender  Video Category
# Female  ASMR              4.294118
#         Comedy            4.166667
#         Entertainment     4.757576
#         Gaming            5.235294
#         Jokes/Memes       4.622642
#         Life Hacks        4.279070
#         Pranks            5.157895
#         Trends            5.651163
#         Vlogs             5.156250
# Male    ASMR              4.888889
#         Comedy            5.266667
#         Entertainment     5.310345
#         Gaming            4.910448
#         Jokes/Memes       4.736842
#         Life Hacks        5.200000
#         Pranks            4.019231
#         Trends            5.261905
#         Vlogs             4.915254
# Other   ASMR              5.111111
#         Comedy            4.625000
#         Entertainment     5.363636
#         Gaming            4.888889
#         Jokes/Memes       4.322581
#         Life Hacks        5.172414
#         Pranks            5.000000
#         Trends            4.000000
# ...

# %%
sns.barplot(x='Gender',y='Satisfaction',hue='Video Category',data=data)
plt.title('Average Satisfaction by Gender and Video Category');

# %% [markdown]
# # What is the satisfaction level of users who spend more than 10 hours on the platform?

# %%
satisfaction=data[data['Total Time Spent']>10]['Satisfaction'].mean()

# %%
satisfaction
# Out:
# 4.868605817452357

# %% [markdown]
# * Satisfaction level of users spending more than 10 hours: 4.868605817452357

# %% [markdown]
# #  Which age group watches the most videos?

# %%
# Define the bins and labels
age_bins = [0, 18, 30, 45, 60, 100]
age_labels = ['Teenager', 'Young Adult', 'Adult', 'Middle-aged', 'Senior']

# Categorize Age into bins
data['Age Group'] = pd.cut(data['Age'], bins=age_bins, labels=age_labels)

# %%
print(data[['Age', 'Age Group']].head())
# Out:
#    Age    Age Group
# 0   56  Middle-aged
# 1   46  Middle-aged
# 2   32        Adult
# 3   60  Middle-aged
# 4   25  Young Adult

# %%
data.groupby('Age Group')['Number of Videos Watched'].mean().plot(kind='pie',autopct='%1.1f%%',shadow=True)
# Out:
# <Axes: ylabel='Number of Videos Watched'>

# %%
data.groupby('Age Group')['Number of Videos Watched'].mean().idxmax()
# Out:
# 'Young Adult'

# %% [markdown]
# # Total Time Spent on Platform by Age Group and Platform Type

# %%
data.groupby(['Age Group','Platform'])['Total Time Spent'].mean()
# Out:
# Age Group    Platform
# Teenager     Facebook     106.600000
#              Instagram    114.800000
#              TikTok       173.571429
#              YouTube      164.750000
# Young Adult  Facebook     163.462963
#              Instagram    158.642857
#              TikTok       159.214286
#              YouTube      153.382353
# Adult        Facebook     149.308642
#              Instagram    145.460674
#              TikTok       148.377778
#              YouTube      140.298507
# Middle-aged  Facebook     156.227273
#              Instagram    139.833333
#              TikTok       138.168831
#              YouTube      167.392405
# Senior       Facebook     168.666667
#              Instagram    163.750000
#              TikTok       170.482759
#              YouTube      136.892857
# Name: Total Time Spent, dtype: float64

# %%
sns.barplot(x='Age Group',y='Total Time Spent',hue='Platform',data=data);
plt.title('Total Time Spent on Platform by Age Group and Platform Type');

# %% [markdown]
# # Distribution of Addiction

# %%
addiction_bins = [0, 2, 5, 7]
addiction_labels = ['Low', 'Moderate', 'High']

# Categorize Addiction Level into bins
data['Addiction Category'] = pd.cut(data['Addiction Level'], bins=addiction_bins, labels=addiction_labels)

# %%
data['Addiction Category'].value_counts().plot(kind='barh',title='Distribution of Addiction Category',xlabel='counts');

# %% [markdown]
# # Total Time Spent by Age Group and Addiction Category

# %%
data.groupby(['Age Group','Addiction Category'])['Total Time Spent'].mean()
# Out:
# Age Group    Addiction Category
# Teenager     Low                   160.100000
#              Moderate              131.000000
#              High                  205.000000
# Young Adult  Low                   145.342105
#              Moderate              164.980198
#              High                  163.315789
# Adult        Low                   139.038462
#              Moderate              150.321918
#              High                  163.678571
# Middle-aged  Low                   158.854167
#              Moderate              147.496183
#              High                  138.730769
# Senior       Low                   161.681818
#              Moderate              138.970588
#              High                  155.500000
# Name: Total Time Spent, dtype: float64

# %%
sns.barplot(x='Age Group',y='Total Time Spent',hue='Addiction Category',data=data);
plt.title('Total Time Spent by Age Group and Addiction Category');

# %% [markdown]
# # Scroll Rate Across Video Categories by Addiction Level

# %%
plt.figure(figsize=(15,6))
plt.title('Scroll Rate Across Video Categories by Addiction Level')
sns.lineplot(x='Video Category',y='Scroll Rate',hue='Addiction Category',data=data);

# %% [markdown]
# # Scroll Rate by Video Length Across Age Groups

# %%
plt.figure(figsize=(15,6))
plt.title('Scroll Rate by Video Length Across Age Groups')
sns.lineplot(x='Video Length',y='Scroll Rate',hue='Age Group',data=data);

# %% [markdown]
# # Importance Score Across Video Categories by Age Group

# %%
data.groupby(['Video Category','Age Group'])['Importance Score'].mean()
# Out:
# Video Category  Age Group
# ASMR            Teenager       1.500000
#                 Young Adult    5.172414
#                 Adult          4.500000
#                 Middle-aged    5.142857
#                 Senior         4.000000
# Comedy          Teenager       4.000000
#                 Young Adult    5.000000
#                 Adult          4.100000
#                 Middle-aged    5.000000
#                 Senior         2.000000
# Entertainment   Teenager       6.500000
#                 Young Adult    5.160000
#                 Adult          4.925926
#                 Middle-aged    5.205882
#                 Senior         6.416667
# Gaming          Teenager       7.000000
#                 Young Adult    5.923077
#                 Adult          4.959184
#                 Middle-aged    5.558824
#                 Senior         5.111111
# Jokes/Memes     Teenager       8.500000
#                 Young Adult    5.425532
#                 Adult          5.173077
# ...

# %%
plt.figure(figsize=(20,6))
plt.title('Importance Score Across Video Categories by Age Group')
sns.barplot(x='Video Category',y='Importance Score',hue='Age Group',data=data);

# %% [markdown]
# # Satisfaction Levels by Watch Reason Across Age Groups

# %%
data.groupby(['Watch Reason','Age Group'])['Satisfaction'].mean()
# Out:
# Watch Reason     Age Group
# Boredom          Teenager       5.500000
#                  Young Adult    4.465753
#                  Adult          4.648352
#                  Middle-aged    4.658537
#                  Senior         5.347826
# Entertainment    Teenager       5.000000
#                  Young Adult    4.661290
#                  Adult          4.829545
#                  Middle-aged    4.911392
#                  Senior         4.777778
# Habit            Teenager       3.800000
#                  Young Adult    5.011765
#                  Adult          5.223214
#                  Middle-aged    4.791304
#                  Senior         5.272727
# Procrastination  Teenager       4.750000
#                  Young Adult    4.464286
#                  Adult          5.444444
#                  Middle-aged    4.722222
#                  Senior         5.500000
# Name: Satisfaction, dtype: float64

# %%
plt.figure(figsize=(20,6))
plt.title('Satisfaction Levels by Watch Reason Across Age Groups')
sns.barplot(x='Watch Reason',y='Satisfaction',hue='Age Group',data=data);

# %%
data.groupby(['Age Group'])['Self Control'].mean()
# Out:
# Age Group
# Teenager       7.120000
# Young Adult    7.254032
# Adult          6.978593
# Middle-aged    7.176282
# Senior         6.772727
# Name: Self Control, dtype: float64

# %% [markdown]
# # Platform Usage Frequency

# %%
data.groupby(['Platform','Frequency'])['Engagement'].mean()
# Out:
# Platform   Frequency
# Facebook   Afternoon    5249.877193
#            Evening      5378.519481
#            Morning      5525.083333
#            Night        4912.031746
# Instagram  Afternoon    4758.407407
#            Evening      4856.764045
#            Morning      4247.416667
#            Night        5754.056180
# TikTok     Afternoon    4486.698413
#            Evening      4630.302083
#            Morning      5282.484848
#            Night        5189.777778
# YouTube    Afternoon    5060.632653
#            Evening      4981.145631
#            Morning      4122.000000
#            Night        4828.917808
# Name: Engagement, dtype: float64

# %%
sns.barplot(x='Platform',y='Engagement', hue='Frequency', data=data)
plt.title('Platform Usage Frequency')
plt.show()

# %% [markdown]
# # Addiction Level vs Productivity Loss

# %%
sns.scatterplot(x=data['Addiction Level'], y=data['ProductivityLoss'])
plt.title('Addiction Level vs Productivity Loss')
plt.show()

# %% [markdown]
# # Frequency Distribution

# %%
data['Frequency'].value_counts().plot(kind='pie',explode=(0,0,0,0.1),shadow=True,autopct="%1.1f%%")
plt.title('Frequency Distribution');

# %% [markdown]
# # Importance Score by Watch Reason Across CurrentActivity

# %%
data.groupby(['Watch Reason','CurrentActivity'])['Importance Score'].mean()
# Out:
# Watch Reason     CurrentActivity
# Boredom          At home            4.979592
#                  At school          4.987013
#                  At work            4.903226
#                  Commuting          5.250000
# Entertainment    At home            4.687500
#                  At school          5.402778
#                  At work            5.318182
#                  Commuting          4.933333
# Habit            At home            5.401408
#                  At school          5.355556
#                  At work            5.102564
#                  Commuting          4.482759
# Procrastination  At home            5.444444
#                  At school          5.375000
#                  At work            4.964286
#                  Commuting          4.800000
# Name: Importance Score, dtype: float64

# %%
plt.figure(figsize=(20,6))
plt.title('Importance Score by Watch Reason Across CurrentActivity')
sns.barplot(x='Watch Reason',y='Importance Score',hue='CurrentActivity',data=data);

# %% [markdown]
# # Time Spent on Video by Watch Reason and Engagement Frequency

# %%
data.groupby(['Watch Reason','Frequency'])['Time Spent On Video'].mean()
# Out:
# Watch Reason     Frequency
# Boredom          Afternoon    16.557692
#                  Evening      14.720721
#                  Morning      16.861111
#                  Night        14.358974
# Entertainment    Afternoon    14.444444
#                  Evening      14.222222
#                  Morning      15.290323
#                  Night        13.312500
# Habit            Afternoon    14.705128
#                  Evening      16.090909
#                  Morning      13.566667
#                  Night        16.209091
# Procrastination  Afternoon    15.033333
#                  Evening      13.558140
#                  Morning      16.666667
#                  Night        14.578947
# Name: Time Spent On Video, dtype: float64

# %%
plt.figure(figsize=(20,6))
plt.title('Time Spent on Video by Watch Reason and Engagement Frequency')
sns.barplot(x='Watch Reason',y='Time Spent On Video',hue='Frequency',data=data);

# %% [markdown]
# # Total Time Spent by Gender and Platform

# %%
data.groupby(['Gender','Platform'])['Total Time Spent'].mean()
# Out:
# Gender  Platform
# Female  Facebook     151.361111
#         Instagram    137.717391
#         TikTok       154.433735
#         YouTube      152.360000
# Male    Facebook     160.973913
#         Instagram    151.969466
#         TikTok       144.776978
#         YouTube      151.751938
# Other   Facebook     143.676471
#         Instagram    152.454545
#         TikTok       163.823529
#         YouTube      156.565217
# Name: Total Time Spent, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Gender', y='Total Time Spent', hue='Platform', data=data)
plt.title('Total Time Spent by Gender and Platform')
plt.show()

# %% [markdown]
# # Total Time Spent by Watch Time and Platform

# %%
data.groupby(['Watch Time','Platform'])['Total Time Spent'].mean()
# Out:
# Watch Time  Platform
# 10:15 PM    Facebook     149.076923
#             Instagram    162.571429
#             TikTok       182.750000
#             YouTube      135.684211
# 11:30 PM    Facebook     149.666667
#                             ...
# 9:15 AM     YouTube      117.750000
# 9:55 AM     Facebook     121.500000
#             Instagram    144.500000
#             TikTok       164.571429
#             YouTube      167.200000
# Name: Total Time Spent, Length: 64, dtype: float64

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='Watch Time', y='Total Time Spent', hue='Platform', data=data)
plt.title('Total Time Spent by Watch Time and Platform')
plt.show()

# %% [markdown]
# # Platform vs Device Type

# %%
# Cross-tabulation for 'Platform' and 'Device Type'
platform_device_ct = pd.crosstab(data['Platform'], data['DeviceType'])
platform_device_ct.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Platform vs Device Type')
plt.show()

# %%
numer=data.select_dtypes(['int64','float32'])

# %%
sns.pairplot(numer)

# %%
data
# Out:
#      UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0         1   56    Male       Pakistan   82812   True           True
# 1         2   46  Female         Mexico   27999  False           True
# 2         3   32  Female  United States   42436  False           True
# 3         4   60    Male         Barzil   62963   True          False
# 4         5   25    Male       Pakistan   22096  False           True
# ..      ...  ...     ...            ...     ...    ...            ...
# 995     996   22    Male          India   74254   True           True
# 996     997   40  Female       Pakistan   27006  False          False
# 997     998   27    Male          India   94218   True           True
# 998     999   61    Male       Pakistan   85344   True          False
# 999    1000   19    Male          India   53840   True           True
#
#         Profession Demographics   Platform  ...     Watch Reason  DeviceType  \
# ...

# %%
data.drop(columns=['Age Group', 'Addiction Category'],inplace=True)

# %%
data.columns
# Out:
# Index(['UserID', 'Age', 'Gender', 'Location', 'Income', 'Debt',
#        'Owns Property', 'Profession', 'Demographics', 'Platform',
#        'Total Time Spent', 'Number of Sessions', 'Video ID', 'Video Category',
#        'Video Length', 'Engagement', 'Importance Score', 'Time Spent On Video',
#        'Number of Videos Watched', 'Scroll Rate', 'Frequency',
#        'ProductivityLoss', 'Satisfaction', 'Watch Reason', 'DeviceType', 'OS',
#        'Watch Time', 'Self Control', 'Addiction Level', 'CurrentActivity',
#        'ConnectionType'],
#       dtype='object')

# %%
data
# Out:
#      UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0         1   56    Male       Pakistan   82812   True           True
# 1         2   46  Female         Mexico   27999  False           True
# 2         3   32  Female  United States   42436  False           True
# 3         4   60    Male         Barzil   62963   True          False
# 4         5   25    Male       Pakistan   22096  False           True
# ..      ...  ...     ...            ...     ...    ...            ...
# 995     996   22    Male          India   74254   True           True
# 996     997   40  Female       Pakistan   27006  False          False
# 997     998   27    Male          India   94218   True           True
# 998     999   61    Male       Pakistan   85344   True          False
# 999    1000   19    Male          India   53840   True           True
#
#         Profession Demographics   Platform  ...  ProductivityLoss  \
# ...

# %% [markdown]
# # User Engagement Prediction Model

# %% [markdown]
# * Goal: Predict the amount of time a user will spend on the platform or a specific video based on their demographics, platform usage history, and other behavioral factors.

# %%
data.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  ...  ProductivityLoss  Satisfaction  \
# 0       Engineer        Rural  Instagram  ...                 3             7
# 1         Artist        Urban  Instagram  ...                 5             5
# 2       Engineer        Rural   Facebook  ...                 6             4
# 3  Waiting staff        Rural    YouTube  ...                 3             7
# 4        Manager        Urban     TikTok  ...                 8             2
#
#       Watch Reason  DeviceType       OS  Watch Time  Self Control  \
# ...

# %%
columns=['Age', 'Gender', 'Income', 'Platform', 'Number of Sessions','DeviceType','Scroll Rate', 'Frequency','Video Category','Engagement','Video Length','Watch Reason']

# %%
data.columns
# Out:
# Index(['UserID', 'Age', 'Gender', 'Location', 'Income', 'Debt',
#        'Owns Property', 'Profession', 'Demographics', 'Platform',
#        'Total Time Spent', 'Number of Sessions', 'Video ID', 'Video Category',
#        'Video Length', 'Engagement', 'Importance Score', 'Time Spent On Video',
#        'Number of Videos Watched', 'Scroll Rate', 'Frequency',
#        'ProductivityLoss', 'Satisfaction', 'Watch Reason', 'DeviceType', 'OS',
#        'Watch Time', 'Self Control', 'Addiction Level', 'CurrentActivity',
#        'ConnectionType'],
#       dtype='object')

# %%
x=data[columns]

# %%
x
# Out:
#      Age  Gender  Income   Platform  Number of Sessions  DeviceType  \
# 0     56    Male   82812  Instagram                  17  Smartphone
# 1     46  Female   27999  Instagram                  14    Computer
# 2     32  Female   42436   Facebook                   6      Tablet
# 3     60    Male   62963    YouTube                  19  Smartphone
# 4     25    Male   22096     TikTok                   6  Smartphone
# ..   ...     ...     ...        ...                 ...         ...
# 995   22    Male   74254     TikTok                   7  Smartphone
# 996   40  Female   27006   Facebook                  15  Smartphone
# 997   27    Male   94218     TikTok                   1  Smartphone
# 998   61    Male   85344    YouTube                  11  Smartphone
# 999   19    Male   53840    YouTube                  17  Smartphone
#
#      Scroll Rate  Frequency Video Category  Engagement  Video Length  \
# 0             87      Night         Pranks        7867            24
# ...

# %%
x.nunique()
# Out:
# Age                    47
# Gender                  3
# Income                996
# Platform                4
# Number of Sessions     19
# DeviceType              3
# Scroll Rate            99
# Frequency               4
# Video Category          9
# Engagement            953
# Video Length           29
# Watch Reason            4
# dtype: int64

# %%
y=data['Total Time Spent']
y
# Out:
# 0       80
# 1      228
# 2       30
# 3      101
# 4      136
#       ...
# 995    144
# 996    231
# 997    165
# 998    151
# 999    167
# Name: Total Time Spent, Length: 1000, dtype: int64

# %%
cat=x.select_dtypes('object')
cat.nunique()
# Out:
# Gender            3
# Platform          4
# DeviceType        3
# Frequency         4
# Video Category    9
# Watch Reason      4
# dtype: int64

# %%
x=pd.get_dummies(x,drop_first=True)

# %%
x
# Out:
#      Age  Income  Number of Sessions  Scroll Rate  Engagement  Video Length  \
# 0     56   82812                  17           87        7867            24
# 1     46   27999                  14           46        5944            19
# 2     32   42436                   6           88        8674            19
# 3     60   62963                  19           93        2477             4
# 4     25   22096                   6            4        3093            19
# ..   ...     ...                 ...          ...         ...           ...
# 995   22   74254                   7           47        5179             1
# 996   40   27006                  15           15        1803             2
# 997   27   94218                   1           44        9290            12
# 998   61   85344                  11           62        2050            15
# 999   19   53840                  17            6        9790             4
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Age  Income  Number of Sessions  Scroll Rate  Engagement  Video Length  \
# 29    44   57481                  10           91        2160             5
# 535   38   37858                   6           65        8625            20
# 695   45   48398                   2           74        3291            13
# 557   47   64014                   3           21        7878             8
# 836   46   91274                  13           97        2940            10
# ..   ...     ...                 ...          ...         ...           ...
# 106   52   89286                   6           30        1701             7
# 270   26   83278                  17           66        4654             4
# 860   64   25842                  15           32        2653            27
# 435   26   24648                  19           12        2280            26
# 102   28   85633                  11           23         730            14
#
# ...

# %%
x_test
# Out:
#      Age  Income  Number of Sessions  Scroll Rate  Engagement  Video Length  \
# 521   25   92982                  18           62        5977            23
# 737   38   88899                   7           18        3275            17
# 740   34   62727                  13           49         824            20
# 660   38   36859                  17           38        6147             3
# 411   61   62604                  16           26        2570             8
# ..   ...     ...                 ...          ...         ...           ...
# 408   54   49033                   4           27        5008            26
# 332   34   63472                  10            1         717             9
# 208   40   36154                  12           89         620            27
# 613   22   96118                  10           41        8605            24
# 78    40   49300                  16           79        3653            28
#
# ...

# %%
scalar=StandardScaler()
scaled_data=scalar.fit_transform(x_train)

# %%
x_train=pd.DataFrame(scaled_data,columns=x_train.columns)
x_train
# Out:
#           Age    Income  Number of Sessions  Scroll Rate  Engagement  \
# 0    0.217341 -0.082957            0.010232     1.417406   -0.958654
# 1   -0.222472 -0.899014           -0.733936     0.533758    1.263956
# 2    0.290643 -0.460689           -1.478105     0.839636   -0.569826
# 3    0.437247  0.188729           -1.292063    -0.961647    1.007144
# 4    0.363945  1.322385            0.568359     1.621325   -0.690497
# ..        ...       ...                 ...          ...         ...
# 795  0.803758  1.239710           -0.733936    -0.655769   -1.116454
# 796 -1.102097  0.989857            1.312527     0.567744   -0.101239
# 797  1.683383 -1.398720            0.940443    -0.587796   -0.789165
# 798 -1.102097 -1.448375            1.684612    -1.267526   -0.917399
# 799 -0.955493  1.087794            0.196274    -0.893674   -1.450275
#
#      Video Length  Gender_Male  Gender_Other  Platform_Instagram  \
# 0       -1.245856     0.953576     -0.436436           -0.579275
# ...

# %%
scaled_test=scalar.transform(x_test)
scaled_test
# Out:
# array([[-1.1753996 ,  1.39341485,  1.49856964, ...,  1.64429429,
#         -0.71774056, -0.37145671],
#        [-0.22247195,  1.22361609, -0.54789418, ..., -0.60816364,
#         -0.71774056, -0.37145671],
#        [-0.51568046,  0.1352073 ,  0.56835881, ...,  1.64429429,
#         -0.71774056, -0.37145671],
#        ...,
#        [-0.0758677 , -0.96987778,  0.38231665, ..., -0.60816364,
#          1.39326109, -0.37145671],
#        [-1.39530598,  1.52383094,  0.01023232, ...,  1.64429429,
#         -0.71774056, -0.37145671],
#        [-0.0758677 , -0.42317818,  1.12648531, ..., -0.60816364,
#         -0.71774056, -0.37145671]])

# %%
x_test=pd.DataFrame(scaled_test,columns=x_test.columns)

# %%
x_test
# Out:
#           Age    Income  Number of Sessions  Scroll Rate  Engagement  \
# 0   -1.175400  1.393415            1.498570     0.431798    0.353597
# 1   -0.222472  1.223616           -0.547894    -1.063607   -0.575327
# 2   -0.515680  0.135207            0.568359    -0.010026   -1.417959
# 3   -0.222472 -0.940559            1.312527    -0.383877    0.412041
# 4    1.463477  0.130092            1.126485    -0.791715   -0.817699
# ..        ...       ...                 ...          ...         ...
# 195  0.950362 -0.434282           -1.106021    -0.757728    0.020463
# 196 -0.515680  0.166189            0.010232    -1.641377   -1.454744
# 197 -0.075868 -0.969878            0.382317     1.349433   -1.488092
# 198 -1.395306  1.523831            0.010232    -0.281918    1.257080
# 199 -0.075868 -0.423178            1.126485     1.009568   -0.445374
#
#      Video Length  Gender_Male  Gender_Other  Platform_Instagram  \
# 0        0.923470    -1.048684      2.291288           -0.579275
# ...

# %%
LR=LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR.predict(x_test)

# %%
from sklearn. metrics import mean_absolute_error,r2_score,mean_squared_error

# %%
# Evaluation
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Absolute Error: 77.23171589342304
# Mean Squared Error: 8031.078856282255
# R-squared: -0.14245688335868478

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(n_estimators=100, random_state=42),
    'GradientBoosting': GradientBoostingRegressor(n_estimators=100, random_state=42)
}
def evaluate_models(models, x_train, y_train,x_test,y_test):
    results = {}
    for name, model in models.items():
        print(f"Evaluating {name}")
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)

        scores = {
            'mae' : mean_absolute_error(y_test, y_pred),
            'mse' : mean_squared_error(y_test, y_pred),
            'r2' : r2_score(y_test, y_pred)
                    }

        print(f"{name} - mae: {scores['mae']:.4f}, mse: {scores['mse']:.4f}, r2: {scores['r2']:.4f}")

        results[name] = scores
        print('=====================================================================================')

    return results

# %%
results = evaluate_models(models, x_train, y_train,x_test,y_test)
# Out:
# Evaluating Linear Regression
# Linear Regression - mae: 77.2317, mse: 8031.0789, r2: -0.1425
# ...
# Evaluating Random Forest
# Random Forest - mae: 77.0885, mse: 8327.6642, r2: -0.1846
# ...
# Evaluating GradientBoosting
# GradientBoosting - mae: 77.4139, mse: 8541.6076, r2: -0.2151
# ...
