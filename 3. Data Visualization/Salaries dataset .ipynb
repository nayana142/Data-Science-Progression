# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("ds_salaries.csv")

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
df.tail()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# ...

# %%
df.shape
# Out:
# (3755, 11)

# %%
df.size
# Out:
# 41305

# %% [markdown]
# ## INFORMATION OF THE DATA SET
# * columns = 11
# * rows = 3755
# * datatypes= object(7),int(4)
# * no null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
df.describe(include='object')
# Out:
#        experience_level employment_type      job_title salary_currency  \
# count              3755            3755           3755            3755
# unique                4               4             93              20
# top                  SE              FT  Data Engineer             USD
# freq               2516            3718           1040            3224
#
#        employee_residence company_location company_size
# count                3755             3755         3755
# unique                 78               72            3
# top                    US               US            M
# freq                 3004             3040         3153

# %%
df.describe(include='all').T
# Out:
#                      count unique            top  freq           mean  \
# work_year           3755.0    NaN            NaN   NaN    2022.373635
# experience_level      3755      4             SE  2516            NaN
# employment_type       3755      4             FT  3718            NaN
# job_title             3755     93  Data Engineer  1040            NaN
# salary              3755.0    NaN            NaN   NaN  190695.571771
# salary_currency       3755     20            USD  3224            NaN
# salary_in_usd       3755.0    NaN            NaN   NaN   137570.38988
# employee_residence    3755     78             US  3004            NaN
# remote_ratio        3755.0    NaN            NaN   NaN      46.271638
# company_location      3755     72             US  3040            NaN
# company_size          3755      3              M  3153            NaN
#
#                               std     min       25%       50%       75%  \
# ...

# %%
df.nunique()
# Out:
# work_year                4
# experience_level         4
# employment_type          4
# job_title               93
# salary                 815
# salary_currency         20
# salary_in_usd         1035
# employee_residence      78
# remote_ratio             3
# company_location        72
# company_size             3
# dtype: int64

# %%
for i in df.columns:
    print(i,':',df[i].unique())
# Out:
# work_year : [2023 2022 2020 2021]
# experience_level : ['SE' 'MI' 'EN' 'EX']
# employment_type : ['FT' 'CT' 'FL' 'PT']
# job_title : ['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
#  'BI Data Engineer' 'Director of Data Science'
#  'Machine Learning Scientist' 'MLOps Engineer' 'AI Scientist'
# ...

# %% [markdown]
# ### Cleaning the dataset
# Remove all duplicated values

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 1171

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.size
# Out:
# 28424

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %% [markdown]
# ### How many Senior-level Data Analysts are employed full-time?

# %%
datafilter=df[(df['experience_level']=='SE') & (df['employment_type']=='FT') & (df['job_title']=='Data Analyst')].reset_index(drop=True)
datafilter
# Out:
#      work_year experience_level employment_type     job_title  salary  \
# 0         2023               SE              FT  Data Analyst  130000
# 1         2023               SE              FT  Data Analyst  100000
# 2         2023               SE              FT  Data Analyst  202800
# 3         2023               SE              FT  Data Analyst  104300
# 4         2023               SE              FT  Data Analyst  145000
# ..         ...              ...             ...           ...     ...
# 214       2022               SE              FT  Data Analyst  105000
# 215       2021               SE              FT  Data Analyst   80000
# 216       2021               SE              FT  Data Analyst  200000
# 217       2021               SE              FT  Data Analyst   54000
# 218       2021               SE              FT  Data Analyst   90000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %% [markdown]
# ### Filter employees from large companies who work at least 50% remotely.

# %%
datafilter2=df[(df['company_size']=='L') & (df['remote_ratio']>=50)].reset_index(drop=True)
datafilter2
# Out:
#      work_year experience_level employment_type                  job_title  \
# 0         2023               SE              FT   Principal Data Scientist
# 1         2023               EN              FT       Data Quality Analyst
# 2         2023               EN              FT    Compliance Data Analyst
# 3         2022               MI              FT  Machine Learning Engineer
# 4         2022               EN              FT               AI Developer
# ..         ...              ...             ...                        ...
# 309       2021               SE              FT            Data Specialist
# 310       2020               SE              FT             Data Scientist
# 311       2021               MI              FT   Principal Data Scientist
# 312       2020               EN              CT      Business Data Analyst
# 313       2021               SE              FT       Data Science Manager
#
# ...

# %%
df3=df[(df['work_year']==2023)&(df['job_title']=='ML Engineer')].reset_index(drop=True)
df3
# Out:
#     work_year experience_level employment_type    job_title  salary  \
# 0        2023               MI              CT  ML Engineer   30000
# 1        2023               MI              CT  ML Engineer   25500
# 2        2023               MI              FT  ML Engineer  160000
# 3        2023               MI              FT  ML Engineer  147000
# 4        2023               SE              FT  ML Engineer  260000
# 5        2023               SE              FT  ML Engineer  110000
# 6        2023               SE              FT  ML Engineer  220000
# 7        2023               SE              FT  ML Engineer  150000
# 8        2023               SE              FT  ML Engineer  200000
# 9        2023               SE              FT  ML Engineer  135000
# 10       2023               SE              FT  ML Engineer  234100
# 11       2023               SE              FT  ML Engineer  203500
# 12       2023               SE              FT  ML Engineer  289076
# ...

# %% [markdown]
# ### How many mid-level (MI) data engineers are working in the UK with a salary between 80,000 and 100,000 USD?

# %%
DE=df[(df['experience_level']=='MI') & (df['job_title']=='Data Engineer') & (df['salary_in_usd']>=80000) & (df['salary_in_usd']>=100000)].reset_index(drop=True)
DE
# Out:
#     work_year experience_level employment_type      job_title  salary  \
# 0        2023               MI              FT  Data Engineer  162500
# 1        2023               MI              FT  Data Engineer  130000
# 2        2023               MI              FT  Data Engineer  100000
# 3        2023               MI              FT  Data Engineer  180000
# 4        2023               MI              FT  Data Engineer  125000
# ..        ...              ...             ...            ...     ...
# 59       2021               MI              FT  Data Engineer  110000
# 60       2021               MI              FT  Data Engineer  112000
# 61       2021               MI              FT  Data Engineer  111775
# 62       2020               MI              FT  Data Engineer  110000
# 63       2020               MI              FT  Data Engineer  130800
#
#    salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %% [markdown]
# ### How does salary in USD vary with experience level (junior, Mid, Senior)?

# %%
df1=df.groupby(['experience_level','job_title'])['salary_in_usd'].mean().to_frame().reset_index()
df1
# Out:
#     experience_level                      job_title  salary_in_usd
# 0                 EN  3D Computer Vision Researcher   35000.000000
# 1                 EN                   AI Developer  130884.500000
# 2                 EN                  AI Programmer   55000.000000
# 3                 EN                   AI Scientist   52781.285714
# 4                 EN             Analytics Engineer  130000.000000
# ..               ...                            ...            ...
# 187               SE         Product Data Scientist    8000.000000
# 188               SE              Research Engineer  174773.181818
# 189               SE             Research Scientist  171229.588235
# 190               SE         Software Data Engineer   50000.000000
# 191               SE           Staff Data Scientist  105000.000000
#
# [192 rows x 3 columns]

# %% [markdown]
# ### salary changes across different experience levels.

# %%
plt.figure(figsize=(10,6))
plt.title("salary changes across different experience levels",color='red')
plt.bar(df1['experience_level'],df1['salary_in_usd'],color='grey')
plt.xlabel("experience_level")
plt.ylabel("average salary_in_usd")           
plt.show()

# %% [markdown]
# ### What is the average remote work ratio for companies of different sizes and locations?

# %%
df2=df.groupby(['company_size','company_location'])['remote_ratio'].mean().to_frame().reset_index()
df2
# Out:
#     company_size company_location  remote_ratio
# 0              L               AE      0.000000
# 1              L               AR    100.000000
# 2              L               AS    100.000000
# 3              L               AT     33.333333
# 4              L               AU     56.250000
# ..           ...              ...           ...
# 128            S               PT     50.000000
# 129            S               SE    100.000000
# 130            S               SK    100.000000
# 131            S               UA     50.000000
# 132            S               US     82.075472
#
# [133 rows x 3 columns]

# %% [markdown]
# ### Compare the remote work flexibility offered by companies of different sizes.

# %%
plt.figure(figsize=(10,5))
plt.title('Remote Ratio Distribution by Company Size')
plt.hist(df2['remote_ratio'],bins=10,color='pink',edgecolor='black')
plt.xlabel('remote_ratio')
plt.ylabel('frequency')
;
# Out:
# ''

# %% [markdown]
# ### Group by employment_type and plot the average salary_in_usd for each type.

# %%
df3=df.groupby('employment_type')['salary_in_usd'].mean().to_frame().reset_index()
df3
# Out:
#   employment_type  salary_in_usd
# 0              CT  113446.900000
# 1              FL   51807.800000
# 2              FT  134434.613271
# 3              PT   39533.705882

# %% [markdown]
# ### Compare salaries across different types of employment

# %%
plt.title('Salary Distribution by Employment Type')
plt.barh(df3['employment_type'],df3['salary_in_usd'],color='skyblue')
plt.xlabel('employment_type')
plt.ylabel('avg salary_in_usd')
plt.show()
